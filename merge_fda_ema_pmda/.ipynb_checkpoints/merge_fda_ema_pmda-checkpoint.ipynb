# %%
import os
import pandas as pd
import time
import math
import re
import psycopg2 as pg

# %%
def findSynonyms (string, synonyms):
    synonymIndices = []
    synonymIDs = list(synonyms.id)
    synonymsName = list(synonyms.name)
    if string in synonymsName:
        index = synonymsName.index(string)
        idNumber = synonymIDs[index]
        for ind, row in synonyms.iterrows():
            if row['id']==idNumber:
                synonymIndices.append(ind)
        for i in synonyms.name[synonymIndices]:
            i = i.upper()
    return list(synonyms.name[synonymIndices])


def build_map(list1, list2):
    print("map builder not written yet")

def mergeDrugLists(list1,list2, synonyms):
    newList = []
    
    for item in list1:
        newList.append(item)
        
    for item in list2:
        if item in newList:
            print("found ", item, " in FDA/EMA resources")
        if item not in newList:
            syns = findSynonyms(item, synonyms)
            foundSynonym = False
            for syn in syns:
                if syn in newList:
                    found=True
                    print("found synonym for ", item, " in FDA/EMA resources")

            if not foundSynonym:
                print("could not find synonym for ", item, " in list 1. Adding it to the list.")
                newList.append(item)
    return newList

      
fda_ema_list = pd.read_excel("../merge_fda_ema/fda_ema_merged_list.xlsx")['Drug Name']
pmda_list = pd.read_excel("../pmda_ingest/pmda_list.xlsx")['Drug Name']
connection = pg.connect(database="drugcentral", user="drugman", password="dosage", host="unmtid-dbs.net", port=5433)
synonyms = pd.read_sql("""select synonyms.* from synonyms""", con=connection)
DrugCentralEntries = pd.read_sql("""select structures.* from structures""", con=connection)
synonyms['name'] = synonyms['name'].str.upper()

fda_ema_pmda_list = mergeDrugLists(fda_ema_list, pmda_list, synonyms)
final_list = list(set(fda_ema_pmda_list).difference(pd.read_excel("force_merge_fields.xlsx")))
sheetData = pd.DataFrame(data=[final_list]).transpose()
sheetData.columns = ['Drug Name']
sheetData.to_excel("fda_ema_pmda_merged_list.xlsx")
# Out:
# /var/folders/gm/d722cfgx1tdd8x4b5b1kd6j80000gn/T/ipykernel_81379/1245211153.py:45: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   synonyms = pd.read_sql("""select synonyms.* from synonyms""", con=connection)
# /var/folders/gm/d722cfgx1tdd8x4b5b1kd6j80000gn/T/ipykernel_81379/1245211153.py:46: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   DrugCentralEntries = pd.read_sql("""select structures.* from structures""", con=connection)
# could not find synonym for  (1) UMECLIDINIUM BROMIDE; (2) VILANTEROL TRIFENATATE  in list 1. Adding it to the list.
# could not find synonym for  (1)(2) LANSOPRAZOLE (3)(4) OMEPRAZOLE (5) SODIUM RABEPRAZOLE (6)(7)(8)(9)(10)(11) AMOXICILLIN HYDRATE (12)(13) CLARITHROMYCIN (14) METRONIDAZOLE (15) LANSOPRAZOLE; AMOXICILLIN HYDRATE; CLARITHROMYCIN  in list 1. Adding it to the list.
# could not find synonym for  (1)(2) LANSOPRAZOLE (3)(4)(5) OMEPRAZOLE (6)(7) RABEPRAZOLE SODIUM (8) ESOMEPRAZOLE MAGNESIUM HYDRATE (9)(10)(11)(12)(13)(14) AMOXICILLIN HYDRATE (15)(16)(17)(18) CLARITHROMYCIN (19) METRONIDAZOLE (20) LANSOPRAZOLE; AMOXICILLIN HYDRATE; CLARITHROMYCIN  in list 1. Adding it to the list.
# could not find synonym for  (21) LANSOPRAZOLE; AMOXICILLIN HYDRATE; METRONIDAZOLE  in list 1. Adding it to the list.
# could not find synonym for  1) 2) CABOTEGRAVIR  CABOTEGRAVIR SODIUM  5) RILPIVIRINE  in list 1. Adding it to the list.
# found synonym for  5-FLUOROURACIL  in FDA/EMA resources
# could not find synonym for  5-FLUOROURACIL  in list 1. Adding it to the list.
# found  ABACAVIR SULFATE  in FDA/EMA resources
# found synonym for  ABALOPARATIDE ACETATE  in FDA/EMA resources
# could not find synonym for  ABALOPARATIDE ACETATE  in list 1. Adding it to the list.
# found  ABATACEPT  in FDA/EMA resources
# found  ABEMACICLIB  in FDA/EMA resources
# found  ABIRATERONE ACETATE  in FDA/EMA resources
# found  ABROCITINIB  in FDA/EMA resources
# found  ACALABRUTINIB  in FDA/EMA resources
# found  ACAMPROSATE CALCIUM  in FDA/EMA resources
# could not find synonym for  ACENEURAMIC ACID  in list 1. Adding it to the list.
# found  ACETAMINOPHEN  in FDA/EMA resources
# found  ACETYLCHOLINE CHLORIDE  in FDA/EMA resources
# found  ACETYLCYSTEINE  in FDA/EMA resources
# found synonym for  ACICLOVIR  in FDA/EMA resources
# found synonym for  ACICLOVIR  in FDA/EMA resources
# could not find synonym for  ACICLOVIR  in list 1. Adding it to the list.
# found  ACLIDINIUM BROMIDE  in FDA/EMA resources
# could not find synonym for  ACOTIAMIDE HYDROCHLORIDE HYDRATE  in list 1. Adding it to the list.
# found synonym for  ACTINOMYCIN D  in FDA/EMA resources
# could not find synonym for  ACTINOMYCIN D  in list 1. Adding it to the list.
# found  ADALIMUMAB  in FDA/EMA resources
# found  ADAPALENE  in FDA/EMA resources
# found  ADAPALENE; BENZOYL PEROXIDE  in FDA/EMA resources
# could not find synonym for  ADEFOVIR PIVOXIL  in list 1. Adding it to the list.
# found  ADENOSINE  in FDA/EMA resources
# could not find synonym for  ADSORBED CELL CULTURE- DERIVED INFLUENZA VACCINE (H5N1)  in list 1. Adding it to the list.
# could not find synonym for  ADSORBED DIPHTHERIA- PURIFIED PERTUSSIS- TETANUS COMBINED VACCINE  in list 1. Adding it to the list.
# could not find synonym for  ADSORBED DIPHTHERIA- PURIFIED PERTUSSIS- TETANUS-INACTIVATED POLIO (SALK VACCINE) COMBINED VACCINE  in list 1. Adding it to the list.
# could not find synonym for  ADSORBED DIPHTHERIA- PURIFIED PERTUSSIS-TETANUS- INACTIVATED POLIO (SABIN STRAIN) COMBINED VACCINE  in list 1. Adding it to the list.
# could not find synonym for  ADSORBED INFLUENZA VACCINE (H5N1)  in list 1. Adding it to the list.
# found synonym for  AFATINIB MALEATE  in FDA/EMA resources
# found synonym for  AFATINIB MALEATE  in FDA/EMA resources
# could not find synonym for  AFATINIB MALEATE  in list 1. Adding it to the list.
# found  AFLIBERCEPT  in FDA/EMA resources
# could not find synonym for  AFLIBERCEPT BETA  in list 1. Adding it to the list.
# found  AGALSIDASE ALFA  in FDA/EMA resources
# could not find synonym for  AGALSIDASE BETA  [AGALSIDASE BETA BIOSIMILAR 1]  in list 1. Adding it to the list.
# could not find synonym for  ALAFENAMIDE FUMARATE  in list 1. Adding it to the list.
# found  ALBUTREPENONACOG ALFA  in FDA/EMA resources
# found  ALECTINIB HYDROCHLORIDE  in FDA/EMA resources
# found  ALEMTUZUMAB  in FDA/EMA resources
# found synonym for  ALENDRONATE SODIUM HYDRATE  in FDA/EMA resources
# found synonym for  ALENDRONATE SODIUM HYDRATE  in FDA/EMA resources
# could not find synonym for  ALENDRONATE SODIUM HYDRATE  in list 1. Adding it to the list.
# found  ALGLUCOSIDASE ALFA  in FDA/EMA resources
# found  ALIROCUMAB  in FDA/EMA resources
# found synonym for  ALISKIREN FUMARATE  in FDA/EMA resources
# found synonym for  ALISKIREN FUMARATE  in FDA/EMA resources
# could not find synonym for  ALISKIREN FUMARATE  in list 1. Adding it to the list.
# could not find synonym for  ALISKIREN FUMARATE; AMLODIPINE BESYLATE  in list 1. Adding it to the list.
# found  ALOGLIPTIN BENZOATE  in FDA/EMA resources
# found  ALOGLIPTIN BENZOATE; METFORMIN HYDROCHLORIDE  in FDA/EMA resources
# found  ALOGLIPTIN BENZOATE; PIOGLITAZONE HYDROCHLORIDE  in FDA/EMA resources
# could not find synonym for  ALPROSTADIL ALFADEX  in list 1. Adding it to the list.
# found  ALTEPLASE  in FDA/EMA resources
# could not find synonym for  ALUMINUM POTASSIUM SULFATE; TANNIC ACID  in list 1. Adding it to the list.
# found  AMBRISENTAN  in FDA/EMA resources
# could not find synonym for  AMENAMEVIR  in list 1. Adding it to the list.
# found  AMIKACIN SULFATE  in FDA/EMA resources
# found  AMINOLEVULINIC ACID HYDROCHLORIDE  in FDA/EMA resources
# found  AMIODARONE HYDROCHLORIDE  in FDA/EMA resources
# found  AMITRIPTYLINE HYDROCHLORIDE  in FDA/EMA resources
# could not find synonym for  AMLODIPINE BESILATE; ATORVASTATIN CALCIUM HYDRATE  in list 1. Adding it to the list.
# found synonym for  AMOXICILLIN HYDRATE  in FDA/EMA resources
# could not find synonym for  AMOXICILLIN HYDRATE  in list 1. Adding it to the list.
# found  AMPHOTERICIN B  in FDA/EMA resources
# found  AMPICILLIN SODIUM  in FDA/EMA resources
# could not find synonym for  ANAGLIPTIN  in list 1. Adding it to the list.
# could not find synonym for  ANAGLIPTIN; METFORMIN HYDROCHLORIDE  in list 1. Adding it to the list.
# found synonym for  ANAGRELIDE HYDROCHLORIDE HYDRATE  in FDA/EMA resources
# found synonym for  ANAGRELIDE HYDROCHLORIDE HYDRATE  in FDA/EMA resources
# could not find synonym for  ANAGRELIDE HYDROCHLORIDE HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  ANAMORELIN HYDROCHLORIDE  in list 1. Adding it to the list.
# found  ANDEXANET ALFA  in FDA/EMA resources
# found synonym for  ANHYDROUS CAFFEINE  in FDA/EMA resources
# found synonym for  ANHYDROUS CAFFEINE  in FDA/EMA resources
# could not find synonym for  ANHYDROUS CAFFEINE  in list 1. Adding it to the list.
# could not find synonym for  ANHYDROUS ETHANOL  in list 1. Adding it to the list.
# could not find synonym for  ANHYDROUS SODIUM SULFATE; POTASSIUM SULFATE; MAGNESIUM SULFATE HYDRATE  in list 1. Adding it to the list.
# found  ANIFROLUMAB  in FDA/EMA resources
# could not find synonym for  ANTI-HUMAN THYMOCYTE IMMUNOGLOBULIN, EQUINE  in list 1. Adding it to the list.
# could not find synonym for  ANTI-HUMAN THYMOCYTE IMMUNOGLOBULIN, RABBIT  in list 1. Adding it to the list.
# could not find synonym for  ANTI-INHIBITOR COAGULANT COMPLEX  in list 1. Adding it to the list.
# could not find synonym for  ANTITHROMBIN GAMMA  in list 1. Adding it to the list.
# could not find synonym for  APADAMTASE ALFA; CINAXADAMTASE ALFA  in list 1. Adding it to the list.
# found  APALUTAMIDE  in FDA/EMA resources
# found  APIXABAN  in FDA/EMA resources
# found synonym for  APOMORPHINE HYDROCHLORIDE HYDRATE  in FDA/EMA resources
# could not find synonym for  APOMORPHINE HYDROCHLORIDE HYDRATE  in list 1. Adding it to the list.
# found  APREMILAST  in FDA/EMA resources
# found  APREPITANT  in FDA/EMA resources
# could not find synonym for  ARBEKACIN SULFATE  in list 1. Adding it to the list.
# found synonym for  ARGATROBAN HYDRATE  in FDA/EMA resources
# could not find synonym for  ARGATROBAN HYDRATE  in list 1. Adding it to the list.
# found  ARIPIPRAZOLE  in FDA/EMA resources
# found  ARSENIC TRIOXIDE  in FDA/EMA resources
# found  ARTEMETHER; LUMEFANTRINE  in FDA/EMA resources
# found  ASCIMINIB HYDROCHLORIDE  in FDA/EMA resources
# found  ASENAPINE MALEATE  in FDA/EMA resources
# found  ASFOTASE ALFA  in FDA/EMA resources
# found  ASPIRIN  in FDA/EMA resources
# could not find synonym for  ASPIRIN DIALMINATE  in list 1. Adding it to the list.
# could not find synonym for  ASPIRIN; VONOPRAZAN FUMARATE  in list 1. Adding it to the list.
# found  ATEZOLIZUMAB  in FDA/EMA resources
# found  ATOMOXETINE HYDROCHLORIDE  in FDA/EMA resources
# found  ATOVAQUONE  in FDA/EMA resources
# found  ATOVAQUONE; PROGUANIL HYDROCHLORIDE  in FDA/EMA resources
# found  AVACOPAN  in FDA/EMA resources
# found  AVALGLUCOSIDASE ALFA  in FDA/EMA resources
# found  AVATROMBOPAG MALEATE  in FDA/EMA resources
# found  AVELUMAB  in FDA/EMA resources
# found  AXITINIB  in FDA/EMA resources
# found  AZACITIDINE  in FDA/EMA resources
# found  AZATHIOPRINE  in FDA/EMA resources
# could not find synonym for  AZILSARTAN  in list 1. Adding it to the list.
# could not find synonym for  AZILSARTAN; AMLODIPINE BESILATE  in list 1. Adding it to the list.
# found synonym for  AZITHROMYCIN HYDRATE  in FDA/EMA resources
# could not find synonym for  AZITHROMYCIN HYDRATE  in list 1. Adding it to the list.
# found  BACLOFEN  in FDA/EMA resources
# found  BALOXAVIR MARBOXIL  in FDA/EMA resources
# found  BARICITINIB  in FDA/EMA resources
# found  BARIUM SULFATE  in FDA/EMA resources
# found  BASILIXIMAB  in FDA/EMA resources
# found synonym for  BAZEDOXIFENE ACETATE  in FDA/EMA resources
# could not find synonym for  BAZEDOXIFENE ACETATE  in list 1. Adding it to the list.
# found synonym for  BECLOMETASONE DIPROPIONATE  in FDA/EMA resources
# found synonym for  BECLOMETASONE DIPROPIONATE  in FDA/EMA resources
# could not find synonym for  BECLOMETASONE DIPROPIONATE  in list 1. Adding it to the list.
# found  BEDAQUILINE FUMARATE  in FDA/EMA resources
# found  BELIMUMAB  in FDA/EMA resources
# could not find synonym for  BELUMOSUDIL MESILATE  in list 1. Adding it to the list.
# found  BENDAMUSTINE HYDROCHLORIDE  in FDA/EMA resources
# found  BENRALIZUMAB  in FDA/EMA resources
# found  BENZOYL PEROXIDE  in FDA/EMA resources
# found synonym for  BENZYLPENICILLIN BENZATHINE HYDRATE  in FDA/EMA resources
# could not find synonym for  BENZYLPENICILLIN BENZATHINE HYDRATE  in list 1. Adding it to the list.
# found synonym for  BENZYLPENICILLIN POTASSIUM  in FDA/EMA resources
# found synonym for  BENZYLPENICILLIN POTASSIUM  in FDA/EMA resources
# could not find synonym for  BENZYLPENICILLIN POTASSIUM  in list 1. Adding it to the list.
# found  BEPOTASTINE BESILATE  in FDA/EMA resources
# found synonym for  BEPRIDIL HYDROCHLORIDE HYDRATE  in FDA/EMA resources
# could not find synonym for  BEPRIDIL HYDROCHLORIDE HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  BERAPROST SODIUM  in list 1. Adding it to the list.
# found  BEROTRALSTAT HYDROCHLORIDE  in FDA/EMA resources
# found  BETAINE  in FDA/EMA resources
# found  BETAMETHASONE SODIUM PHOSPHATE  in FDA/EMA resources
# found  BEVACIZUMAB  in FDA/EMA resources
# found  BEXAROTENE  in FDA/EMA resources
# found  BEZLOTOXUMAB  in FDA/EMA resources
# found  BICTEGRAVIR SODIUM; EMTRICITABINE; TENOFOVIR ALAFENAMIDE FUMARATE  in FDA/EMA resources
# could not find synonym for  BILASTINE  in list 1. Adding it to the list.
# found  BIMATOPROST  in FDA/EMA resources
# found  BIMEKIZUMAB  in FDA/EMA resources
# found  BINIMETINIB  in FDA/EMA resources
# found synonym for  BISOPROLOL  in FDA/EMA resources
# could not find synonym for  BISOPROLOL  in list 1. Adding it to the list.
# found  BISOPROLOL FUMARATE  in FDA/EMA resources
# could not find synonym for  BIXALOMER  in list 1. Adding it to the list.
# found synonym for  BLEOMYCIN HYDROCHLORIDE  in FDA/EMA resources
# could not find synonym for  BLEOMYCIN HYDROCHLORIDE  in list 1. Adding it to the list.
# found  BLINATUMOMAB  in FDA/EMA resources
# could not find synonym for  BLONANSERIN  in list 1. Adding it to the list.
# could not find synonym for  BOROFALAN (10B)  in list 1. Adding it to the list.
# found  BORTEZOMIB  in FDA/EMA resources
# found synonym for  BOSENTAN HYDRATE  in FDA/EMA resources
# found synonym for  BOSENTAN HYDRATE  in FDA/EMA resources
# could not find synonym for  BOSENTAN HYDRATE  in list 1. Adding it to the list.
# found synonym for  BOSUTINIB HYDRATE  in FDA/EMA resources
# found synonym for  BOSUTINIB HYDRATE  in FDA/EMA resources
# could not find synonym for  BOSUTINIB HYDRATE  in list 1. Adding it to the list.
# found  BOTULINUM TOXIN TYPE A  in FDA/EMA resources
# could not find synonym for  BOTULINUM TOXIN TYPE B  in list 1. Adding it to the list.
# found  BRENTUXIMAB VEDOTIN  in FDA/EMA resources
# found  BREXPIPRAZOLE  in FDA/EMA resources
# found  BRIGATINIB  in FDA/EMA resources
# found  BRIMONIDINE TARTRATE  in FDA/EMA resources
# found  BRIMONIDINE TARTRATE; BRINZOLAMIDE  in FDA/EMA resources
# found  BRIMONIDINE TARTRATE; TIMOLOL MALEATE  in FDA/EMA resources
# could not find synonym for  BRINZOLAMIDE TIMOLOL MALEATE  in list 1. Adding it to the list.
# found  BRODALUMAB  in FDA/EMA resources
# found  BROLUCIZUMAB  in FDA/EMA resources
# found  BUDESONIDE  in FDA/EMA resources
# could not find synonym for  BUDESONIDE; FORMOTEROL FUMARATE HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  BUDESONIDE; GLYCOPYRRONIUM BROMIDE; FORMOTEROL FUMARATE HYDRATE  in list 1. Adding it to the list.
# found  BUPRENORPHINE  in FDA/EMA resources
# could not find synonym for  BUROSUMAB (GENETICAL RECOMBINATION)  in list 1. Adding it to the list.
# could not find synonym for  BUSERELIN ACETATE  in list 1. Adding it to the list.
# found  BUSULFAN  in FDA/EMA resources
# found synonym for  CABAZITAXEL ACETONATE  in FDA/EMA resources
# could not find synonym for  CABAZITAXEL ACETONATE  in list 1. Adding it to the list.
# found  CABERGOLINE  in FDA/EMA resources
# found synonym for  CABOZANTINIB MALATE  in FDA/EMA resources
# could not find synonym for  CABOZANTINIB MALATE  in list 1. Adding it to the list.
# could not find synonym for  CALCIPOTRIOL HYDRATE; BETAMETHASONE DIPROPIONATE  in list 1. Adding it to the list.
# found synonym for  CALCIUM FOLINATE  in FDA/EMA resources
# could not find synonym for  CALCIUM FOLINATE  in list 1. Adding it to the list.
# found synonym for  CALCIUM LEVOFOLINATE HYDRATE  in FDA/EMA resources
# found synonym for  CALCIUM LEVOFOLINATE HYDRATE  in FDA/EMA resources
# could not find synonym for  CALCIUM LEVOFOLINATE HYDRATE  in list 1. Adding it to the list.
# found synonym for  CANAGLIFLOZIN HYDRATE  in FDA/EMA resources
# could not find synonym for  CANAGLIFLOZIN HYDRATE  in list 1. Adding it to the list.
# found  CANAKINUMAB  in FDA/EMA resources
# found  CANDESARTAN CILEXETIL  in FDA/EMA resources
# could not find synonym for  CANDESARTAN CILEXETIL; AMLODIPINE BESILATE  in list 1. Adding it to the list.
# found  CANDESARTAN CILEXETIL; HYDROCHLOROTHIAZIDE  in FDA/EMA resources
# found  CAPECITABINE  in FDA/EMA resources
# could not find synonym for  CAPECITABINE - (4) OXALIPLATIN  in list 1. Adding it to the list.
# found  CAPIVASERTIB  in FDA/EMA resources
# found  CAPLACIZUMAB  in FDA/EMA resources
# found synonym for  CAPMATINIB HYDROCHLORIDE HYDRATE  in FDA/EMA resources
# found synonym for  CAPMATINIB HYDROCHLORIDE HYDRATE  in FDA/EMA resources
# could not find synonym for  CAPMATINIB HYDROCHLORIDE HYDRATE  in list 1. Adding it to the list.
# found  CARBOPLATIN  in FDA/EMA resources
# found  CARFILZOMIB  in FDA/EMA resources
# found  CARGLUMIC ACID  in FDA/EMA resources
# found  CARMUSTINE  in FDA/EMA resources
# could not find synonym for  CAROTEGRAST METHYL  in list 1. Adding it to the list.
# found  CARTEOLOL HYDROCHLORIDE  in FDA/EMA resources
# could not find synonym for  CARTEOLOL HYDROCHLORIDE; LATANOPROST  in list 1. Adding it to the list.
# found  CARVEDILOL  in FDA/EMA resources
# could not find synonym for  CASIRIVIMAB; IMDEVIMAB  in list 1. Adding it to the list.
# found  CASPOFUNGIN ACETATE  in FDA/EMA resources
# found  CATRIDECACOG  in FDA/EMA resources
# found  CEFDITOREN PIVOXIL  in FDA/EMA resources
# could not find synonym for  CEFEPIME DIHYDROCHLORIDE  in list 1. Adding it to the list.
# could not find synonym for  CEFIDEROCOL TOSILATE SULFATE HYDRATE  in list 1. Adding it to the list.
# found  CEFOTAXIME SODIUM  in FDA/EMA resources
# found  CEFTOLOZANE  in FDA/EMA resources
# could not find synonym for  CEFTOLOZANE  SULFATE; TAZOBACTAM SODIUM  in list 1. Adding it to the list.
# found  CEFTOLOZANE SULFATE; TAZOBACTAM SODIUM  in FDA/EMA resources
# found  CEFTRIAXONE SODIUM  in FDA/EMA resources
# found  CELECOXIB  in FDA/EMA resources
# could not find synonym for  CELL CULTURE-DERIVED INFLUENZA EMULSION HA VACCINE (H5N1)  in list 1. Adding it to the list.
# could not find synonym for  CELL CULTURE-DERIVED INFLUENZA EMULSION HA VACCINES (PROTOTYPE)  in list 1. Adding it to the list.
# could not find synonym for  CELL CULTURE-DERIVED INFLUENZA VACCINE (H5N1)  in list 1. Adding it to the list.
# could not find synonym for  CELL CULTURE-DERIVED INFLUENZA VACCINES (PROTOTYPE)  in list 1. Adding it to the list.
# found  CEMIPLIMAB  in FDA/EMA resources
# found  CERITINIB  in FDA/EMA resources
# found  CERLIPONASE ALFA  in FDA/EMA resources
# found  CERTOLIZUMAB PEGOL  in FDA/EMA resources
# could not find synonym for  CETILISTAT  in list 1. Adding it to the list.
# found  CETIRIZINE HYDROCHLORIDE  in FDA/EMA resources
# found  CETRORELIX ACETATE  in FDA/EMA resources
# found  CETUXIMAB  in FDA/EMA resources
# could not find synonym for  CETUXIMAB SAROTALOCAN SODIUM  in list 1. Adding it to the list.
# found  CHOLIC ACID  in FDA/EMA resources
# found  CHORIOGONADOTROPIN ALFA  in FDA/EMA resources
# found  CHORIONIC GONADOTROPHIN  in FDA/EMA resources
# found  CICLESONIDE  in FDA/EMA resources
# found  CINACALCET HYDROCHLORIDE  in FDA/EMA resources
# found synonym for  CIPROFLOXACIN  in FDA/EMA resources
# could not find synonym for  CIPROFLOXACIN  in list 1. Adding it to the list.
# found  CISPLATIN  in FDA/EMA resources
# found  CLADRIBINE  in FDA/EMA resources
# found  CLARITHROMYCIN  in FDA/EMA resources
# could not find synonym for  CLAVULANATE POTASSIUM; AMOXICILLIN HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  CLAZOSENTAN SODIUM  in list 1. Adding it to the list.
# found  CLINDAMYCIN PHOSPHATE  in FDA/EMA resources
# could not find synonym for  CLINDAMYCIN PHOSPHATE HYDRATE; BENZOYL PEROXIDE  in list 1. Adding it to the list.
# found  CLOBETASOL PROPIONATE  in FDA/EMA resources
# found  CLOFARABINE  in FDA/EMA resources
# found synonym for  CLOMIFENE CITRATE  in FDA/EMA resources
# could not find synonym for  CLOMIFENE CITRATE  in list 1. Adding it to the list.
# found  CLOMIPHENE CITRATE  in FDA/EMA resources
# found  CLOMIPRAMINE HYDROCHLORIDE  in FDA/EMA resources
# found synonym for  CLOPIDOGREL SULFATE  in FDA/EMA resources
# found synonym for  CLOPIDOGREL SULFATE  in FDA/EMA resources
# could not find synonym for  CLOPIDOGREL SULFATE  in list 1. Adding it to the list.
# found  CLOZAPINE  in FDA/EMA resources
# found  COLCHICINE  in FDA/EMA resources
# found synonym for  COLISTIN SODIUM METHANESULFONATE  in FDA/EMA resources
# could not find synonym for  COLISTIN SODIUM METHANESULFONATE  in list 1. Adding it to the list.
# could not find synonym for  COLLAGENASE (CLOSTRIDIUM HISTOLYTICUM )  in list 1. Adding it to the list.
# could not find synonym for  CONCIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  CONDOLIASE  in list 1. Adding it to the list.
# could not find synonym for  COVID-19 (SARS- COV-2) VACCINE (RECOMBINANT CHIMPANZEE ADENOVIRUS VECTOR)  in list 1. Adding it to the list.
# could not find synonym for  COVID-19 (SARS-COV- 2) VACCINE (RECOMBINANT ADENOVIRUS VECTOR)  in list 1. Adding it to the list.
# found  CRISANTASPASE  in FDA/EMA resources
# found  CRIZOTINIB  in FDA/EMA resources
# could not find synonym for  CROVALIMAB  in list 1. Adding it to the list.
# could not find synonym for  CX-024414  in list 1. Adding it to the list.
# found  CYCLOPHOSPHAMIDE  in FDA/EMA resources
# found  CYCLOSPORINE  in FDA/EMA resources
# found  CYSTEAMINE BITARTRATE  in FDA/EMA resources
# found  CYSTEAMINE HYDROCHLORIDE  in FDA/EMA resources
# found  CYTARABINE  in FDA/EMA resources
# found synonym for  DABIGATRAN ETEXILATE METHANESULFONATE  in FDA/EMA resources
# found synonym for  DABIGATRAN ETEXILATE METHANESULFONATE  in FDA/EMA resources
# could not find synonym for  DABIGATRAN ETEXILATE METHANESULFONATE  in list 1. Adding it to the list.
# found synonym for  DABRAFENIB MESILATE  in FDA/EMA resources
# found synonym for  DABRAFENIB MESILATE  in FDA/EMA resources
# could not find synonym for  DABRAFENIB MESILATE  in list 1. Adding it to the list.
# found  DACARBAZINE  in FDA/EMA resources
# could not find synonym for  DACLATASVIR HYDROCHLORIDE ASUNAPREVIR  in list 1. Adding it to the list.
# could not find synonym for  DACLATASVIR HYDROCHLORIDE; ASUNAPREVIR; BECLABUVIR HYDROCHLORIDE  in list 1. Adding it to the list.
# found synonym for  DACOMITINIB HYDRATE  in FDA/EMA resources
# could not find synonym for  DACOMITINIB HYDRATE  in list 1. Adding it to the list.
# found  DAMOCTOCOG ALFA PEGOL  in FDA/EMA resources
# found  DANICOPAN  in FDA/EMA resources
# found synonym for  DAPAGLIFLOZIN PROPYLENE GLYCOLATE HYDRATE  in FDA/EMA resources
# could not find synonym for  DAPAGLIFLOZIN PROPYLENE GLYCOLATE HYDRATE  in list 1. Adding it to the list.
# found  DAPRODUSTAT  in FDA/EMA resources
# found  DAPTOMYCIN  in FDA/EMA resources
# found  DARATUMUMAB  in FDA/EMA resources
# could not find synonym for  DARATUMUMAB; VORHYALURONIDASE ALFA  in list 1. Adding it to the list.
# found  DARBEPOETIN ALFA  in FDA/EMA resources
# could not find synonym for  DARBEPOETIN ALFA  [DARBEPOETIN ALFA BIOSIMILAR 1]  in list 1. Adding it to the list.
# could not find synonym for  DARBEPOETIN ALFA  [DARBEPOETIN ALFA BIOSIMILAR 2]  in list 1. Adding it to the list.
# could not find synonym for  DARBEPOETIN ALFA (GENETICAL RECOMBINATION) [DARBEPOETIN ALFA BIOSIMILAR 3]  in list 1. Adding it to the list.
# could not find synonym for  DARINAPARSIN  in list 1. Adding it to the list.
# found  DAROLUTAMIDE  in FDA/EMA resources
# found synonym for  DARUNAVIR ETHANOLATE  in FDA/EMA resources
# could not find synonym for  DARUNAVIR ETHANOLATE  in list 1. Adding it to the list.
# could not find synonym for  DARUNAVIR ETHANOLATE; COBICISTAT  in list 1. Adding it to the list.
# could not find synonym for  DARUNAVIR ETHANOLATE; COBICISTAT; EMTRICITABINE; TENOFOVIR ALAFENAMIDE FUMARATE  in list 1. Adding it to the list.
# found synonym for  DASATINIB HYDRATE  in FDA/EMA resources
# could not find synonym for  DASATINIB HYDRATE  in list 1. Adding it to the list.
# found  DAUNORUBICIN HYDROCHLORIDE  in FDA/EMA resources
# could not find synonym for  DAUNORUBICIN HYDROCHLORIDE; CYTARABINE  in list 1. Adding it to the list.
# found  DEFERASIROX  in FDA/EMA resources
# found  DEFIBROTIDE SODIUM  in FDA/EMA resources
# found  DEGARELIX ACETATE  in FDA/EMA resources
# found  DELAMANID  in FDA/EMA resources
# could not find synonym for  DELGOCITINIB  in list 1. Adding it to the list.
# found  DENILEUKIN DIFTITOX  in FDA/EMA resources
# found  DENOSUMAB  in FDA/EMA resources
# could not find synonym for  DERMATOPHAGOIDES FARINAE EXTRACT BULK POWDER; DERMATOPHAGOIDES PTERONYSSINUS EXTRACT BULK POWDER  in list 1. Adding it to the list.
# could not find synonym for  DERMATOPHAGOIDES FARINAE EXTRACT; DERMATOPHAGOIDES PTERONYSSINUS EXTRACT  in list 1. Adding it to the list.
# found  DESFLURANE  in FDA/EMA resources
# found  DESLORATADINE  in FDA/EMA resources
# found synonym for  DESMOPRESSIN ACETATE HYDRATE  in FDA/EMA resources
# could not find synonym for  DESMOPRESSIN ACETATE HYDRATE  in list 1. Adding it to the list.
# found  DEUCRAVACITINIB  in FDA/EMA resources
# found  DEXAMETHASONE  in FDA/EMA resources
# could not find synonym for  DEXAMETHASONE CIPECILATE  in list 1. Adding it to the list.
# found  DEXAMETHASONE SODIUM PHOSPHATE  in FDA/EMA resources
# found  DEXMEDETOMIDINE HYDROCHLORIDE  in FDA/EMA resources
# found  DEXRAZOXANE  in FDA/EMA resources
# found  DIAZOXIDE  in FDA/EMA resources
# could not find synonym for  DICLOFENAC ETALHYALURONATE SODIUM  in list 1. Adding it to the list.
# found  DICLOFENAC SODIUM  in FDA/EMA resources
# could not find synonym for  DIENOGEST  in list 1. Adding it to the list.
# could not find synonym for  DIFAMILAST  in list 1. Adding it to the list.
# found  DIFELIKEFALIN ACETATE  in FDA/EMA resources
# found  DIMETHYL FUMARATE  in FDA/EMA resources
# found  DIMETHYL SULFOXIDE  in FDA/EMA resources
# found  DINOPROSTONE  in FDA/EMA resources
# found  DINUTUXIMAB  in FDA/EMA resources
# could not find synonym for  DIQUAFOSOI SODIUM  in list 1. Adding it to the list.
# found  DOBUTAMINE HYDROCHLORIDE  in FDA/EMA resources
# found synonym for  DOCETAXEL HYDRATE  in FDA/EMA resources
# could not find synonym for  DOCETAXEL HYDRATE  in list 1. Adding it to the list.
# found  DOLUTEGRAVIR SODIUM  in FDA/EMA resources
# could not find synonym for  DOLUTEGRAVIR SODIUM; ABACAVIR SULFATE; LAMIVUDINE  in list 1. Adding it to the list.
# found  DOLUTEGRAVIR SODIUM; LAMIVUDINE  in FDA/EMA resources
# could not find synonym for  DOLUTEGRAVIR SODIUM; RILPIVIRINE  in list 1. Adding it to the list.
# could not find synonym for  DOLUTEGRAVIR SODIUM; RILPIVIRINE  HYDROCHLORIDE  in list 1. Adding it to the list.
# found synonym for  DONEPEZIL  in FDA/EMA resources
# could not find synonym for  DONEPEZIL  in list 1. Adding it to the list.
# found  DONEPEZIL HYDROCHLORIDE  in FDA/EMA resources
# found  DORAVIRINE  in FDA/EMA resources
# found synonym for  DORIPENEM HYDRATE  in FDA/EMA resources
# could not find synonym for  DORIPENEM HYDRATE  in list 1. Adding it to the list.
# found  DORNASE ALFA  in FDA/EMA resources
# found  DORZOLAMIDE HYDROCHLORIDE; TIMOLOL MALEATE  in FDA/EMA resources
# could not find synonym for  DOTINURAD  in list 1. Adding it to the list.
# found synonym for  DOXAPRAM HYDROCHLORIDE HYDRATE  in FDA/EMA resources
# could not find synonym for  DOXAPRAM HYDROCHLORIDE HYDRATE  in list 1. Adding it to the list.
# found  DOXORUBICIN HYDROCHLORIDE  in FDA/EMA resources
# could not find synonym for  DROSPIRENONE; ETHINYLESTRA DIOL BETADEX  in list 1. Adding it to the list.
# could not find synonym for  DROSPIRENONE; ETHINYLESTRADIOL BETADEX  in list 1. Adding it to the list.
# could not find synonym for  DRY ANTI-RHO(D) IMMUNE HUMAN GLOBULIN  in list 1. Adding it to the list.
# found  DULAGLUTIDE  in FDA/EMA resources
# found  DULOXETINE HYDROCHLORIDE  in FDA/EMA resources
# found  DUPILUMAB  in FDA/EMA resources
# found  DURVALUMAB  in FDA/EMA resources
# found  DUTASTERIDE  in FDA/EMA resources
# found  DYDROGESTERONE  in FDA/EMA resources
# found  ECULIZUMAB  in FDA/EMA resources
# found  EDARAVONE  in FDA/EMA resources
# found synonym for  EDOXABAN TOSILATE HYDRATE  in FDA/EMA resources
# found synonym for  EDOXABAN TOSILATE HYDRATE  in FDA/EMA resources
# could not find synonym for  EDOXABAN TOSILATE HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  EFANESOCTOCOG ALFA  in list 1. Adding it to the list.
# found  EFGARTIGIMOD ALFA  in FDA/EMA resources
# could not find synonym for  EFGARTIGIMOD ALFA; VORHYALURONIDASE ALFA  in list 1. Adding it to the list.
# found  EFINACONAZOLE  in FDA/EMA resources
# found synonym for  EFRALOCTOCOG ALFA  in FDA/EMA resources
# could not find synonym for  EFRALOCTOCOG ALFA  in list 1. Adding it to the list.
# found  EFTRENONACOG ALFA  in FDA/EMA resources
# found  ELAPEGADEMASE  in FDA/EMA resources
# could not find synonym for  ELASOMERAN (FORMER INGREDIENT NAME: CX- 024414)  in list 1. Adding it to the list.
# could not find synonym for  ELASOMERAN ELASOMERAN; IMELASOMERAN  in list 1. Adding it to the list.
# could not find synonym for  ELASOMERAN; ELASOMERAN; IMELASOMERAN; ELASOMERAN; DAVESOMERAN  in list 1. Adding it to the list.
# could not find synonym for  ELASOMERAN; ELASOMERAN; IMELASOMERAN; ELASOMERAN; DAVESOMERAN; ANDUSOMERAN  in list 1. Adding it to the list.
# found  ELBASVIR  in FDA/EMA resources
# could not find synonym for  ELDECALCITOL  in list 1. Adding it to the list.
# found  ELIGLUSTAT TARTRATE  in FDA/EMA resources
# could not find synonym for  ELOBIXIBAT HYDRATE  in list 1. Adding it to the list.
# found  ELOSULFASE ALFA  in FDA/EMA resources
# found  ELOTUZUMAB  in FDA/EMA resources
# found  ELRANATAMAB  in FDA/EMA resources
# found  ELTROMBOPAG OLAMINE  in FDA/EMA resources
# could not find synonym for  ELVITEGRAVIR; COBICISTAT; EMTRICITABINE; TENOFOVIR ALAFENAMIDE FUMARATE  in list 1. Adding it to the list.
# could not find synonym for  ELVITEGRAVIR; COBICISTAT; EMTRICITABINE; TENOFOVIR DISOPROXIL FUMARATE  in list 1. Adding it to the list.
# found synonym for  EMEDASTINE FUMARATE  in FDA/EMA resources
# found synonym for  EMEDASTINE FUMARATE  in FDA/EMA resources
# could not find synonym for  EMEDASTINE FUMARATE  in list 1. Adding it to the list.
# found  EMICIZUMAB  in FDA/EMA resources
# found  EMPAGLIFLOZIN  in FDA/EMA resources
# found  EMPAGLIFLOZIN; LINAGLIPTIN  in FDA/EMA resources
# found  EMTRICITABINE  in FDA/EMA resources
# found  EMTRICITABINE; TENOFOVIR ALAFENAMIDE FUMARATE  in FDA/EMA resources
# found  EMTRICITABINE; TENOFOVIR DISOPROXIL FUMARATE  in FDA/EMA resources
# could not find synonym for  EMULSION-ADJUVANTED CELL-CULTURE DERIVED INFLUENZA HA VACCINE (H5N1)  in list 1. Adding it to the list.
# could not find synonym for  EMULSION-ADJUVANTED CELL-CULTURE DERIVED INFLUENZA HA VACCINE (PROTOTYPE)  in list 1. Adding it to the list.
# found  ENALAPRIL MALEATE  in FDA/EMA resources
# could not find synonym for  ENARODUSTAT  in list 1. Adding it to the list.
# found  ENCORAFENIB  in FDA/EMA resources
# found  ENFORTUMAB VEDOTIN  in FDA/EMA resources
# found  ENOXAPARIN SODIUM  in FDA/EMA resources
# could not find synonym for  ENSITRELVIR FUMARIC ACID  in list 1. Adding it to the list.
# found  ENTACAPONE  in FDA/EMA resources
# found synonym for  ENTECAVIR HYDRATE  in FDA/EMA resources
# could not find synonym for  ENTECAVIR HYDRATE  in list 1. Adding it to the list.
# found  ENTRECTINIB  in FDA/EMA resources
# found  ENZALUTAMIDE  in FDA/EMA resources
# found  EPCORITAMAB  in FDA/EMA resources
# found  EPHEDRINE HYDROCHLORIDE  in FDA/EMA resources
# found  EPINASTINE HYDROCHLORIDE  in FDA/EMA resources
# found  EPINEPHRINE  in FDA/EMA resources
# found  EPIRUBICIN HYDROCHLORIDE  in FDA/EMA resources
# found  EPLERENONE  in FDA/EMA resources
# found  EPOETIN BETA  in FDA/EMA resources
# could not find synonym for  EPOETIN BETA PEGOL  in list 1. Adding it to the list.
# could not find synonym for  EPOETIN KAPPA  [EPOETIN ALFA BIOSIMILAR 1]  in list 1. Adding it to the list.
# found  EPOPROSTENOL SODIUM  in FDA/EMA resources
# found  EPTACOG ALFA (ACTIVATED)  in FDA/EMA resources
# found  ERENUMAB  in FDA/EMA resources
# found  ERIBULIN MESYLATE  in FDA/EMA resources
# found  ERLOTINIB  in FDA/EMA resources
# could not find synonym for  ESAXERENONE  in list 1. Adding it to the list.
# found  ESCITALOPRAM OXALATE  in FDA/EMA resources
# could not find synonym for  ESFLURBIPROFEN; MENTHA OIL  in list 1. Adding it to the list.
# found  ESMOLOL HYDROCHLORIDE  in FDA/EMA resources
# found synonym for  ESOMEPRAZOLE MAGNESIUM HYDRATE  in FDA/EMA resources
# found synonym for  ESOMEPRAZOLE MAGNESIUM HYDRATE  in FDA/EMA resources
# found synonym for  ESOMEPRAZOLE MAGNESIUM HYDRATE  in FDA/EMA resources
# found synonym for  ESOMEPRAZOLE MAGNESIUM HYDRATE  in FDA/EMA resources
# could not find synonym for  ESOMEPRAZOLE MAGNESIUM HYDRATE  in list 1. Adding it to the list.
# found  ESTRADIOL  in FDA/EMA resources
# could not find synonym for  ESTRADIOL; LEVONORGESTREL ESTRADIOL  in list 1. Adding it to the list.
# could not find synonym for  ESTRADIOL; NORETHISTERONE ACETATE  in list 1. Adding it to the list.
# found  ESZOPICLONE  in FDA/EMA resources
# found  ETANERCEPT  in FDA/EMA resources
# could not find synonym for  ETANERCEPT  [ETANERCEPT BIOSIMILAR 1]  in list 1. Adding it to the list.
# could not find synonym for  ETANERCEPT  [ETANERCEPT BIOSIMILAR 2]  in list 1. Adding it to the list.
# could not find synonym for  ETANERCEPT (GENETIC RECOMBINATION)  in list 1. Adding it to the list.
# found synonym for  ETELCALCETIDE HYDROCHLORIDE  in FDA/EMA resources
# could not find synonym for  ETELCALCETIDE HYDROCHLORIDE  in list 1. Adding it to the list.
# found  ETHAMBUTOL HYDROCHLORIDE  in FDA/EMA resources
# found synonym for  ETHYL ICOSAPENTATE  in FDA/EMA resources
# could not find synonym for  ETHYL ICOSAPENTATE  in list 1. Adding it to the list.
# found  ETOPOSIDE  in FDA/EMA resources
# found  ETRAVIRINE  in FDA/EMA resources
# found  EVEROLIMUS  in FDA/EMA resources
# found  EVINACUMAB  in FDA/EMA resources
# could not find synonym for  EVOCALCET  in list 1. Adding it to the list.
# found  EVOLOCUMAB  in FDA/EMA resources
# found  EXENATIDE  in FDA/EMA resources
# found  EZETIMIBE  in FDA/EMA resources
# could not find synonym for  EZETIMIBE; ATORVASTATIN CALCIUM HYDRATE  in list 1. Adding it to the list.
# found  EZETIMIBE; ROSUVASTATIN CALCIUM  in FDA/EMA resources
# found  FAMCICLOVIR  in FDA/EMA resources
# found  FARICIMAB  in FDA/EMA resources
# could not find synonym for  FAVIPIRAVIR  in list 1. Adding it to the list.
# found  FEBUXOSTAT  in FDA/EMA resources
# found  FENFLURAMINE HYDROCHLORIDE  in FDA/EMA resources
# found  FENOFIBRATE  in FDA/EMA resources
# found  FENTANYL  in FDA/EMA resources
# found  FENTANYL CITRATE  in FDA/EMA resources
# found  FERRIC AMMONIUM CITRATE  in FDA/EMA resources
# found  FERRIC CARBOXYMALTOSE  in FDA/EMA resources
# found synonym for  FERRIC CITRATE HYDRATE  in FDA/EMA resources
# could not find synonym for  FERRIC CITRATE HYDRATE  in list 1. Adding it to the list.
# found  FERRIC DERISOMALTOSE  in FDA/EMA resources
# found  FESOTERODINE FUMARATE  in FDA/EMA resources
# found  FEXOFENADINE HYDROCHLORIDE  in FDA/EMA resources
# found  FEXOFENADINE HYDROCHLORIDE; PSEUDOEPHEDRINE HYDROCHLORIDE  in FDA/EMA resources
# found  FIDAXOMICIN  in FDA/EMA resources
# found synonym for  FILGOTINIB MALEATE  in FDA/EMA resources
# could not find synonym for  FILGOTINIB MALEATE  in list 1. Adding it to the list.
# found  FILGRASTIM  in FDA/EMA resources
# could not find synonym for  FILGRASTIM  [FILGRASTIM BIOSIMILAR 2]  in list 1. Adding it to the list.
# could not find synonym for  FILGRASTIM  [FILGRASTIM BIOSIMILAR 3]  in list 1. Adding it to the list.
# could not find synonym for  FILGRASTIM (GENETICAL RECOMBINATION)  in list 1. Adding it to the list.
# found  FINASTERIDE  in FDA/EMA resources
# found  FINERENONE  in FDA/EMA resources
# found  FINGOLIMOD HYDROCHLORIDE  in FDA/EMA resources
# found  FLECAINIDE ACETATE  in FDA/EMA resources
# found  FLUCONAZOLE  in FDA/EMA resources
# found  FLUDARABINE PHOSPHATE  in FDA/EMA resources
# found  FLUOROURACIL  in FDA/EMA resources
# found  FLUTICASONE FUROATE  in FDA/EMA resources
# found  FLUTICASONE FUROATE; UMECLIDINIUM BROMIDE; VILANTEROL TRIFENATATE  in FDA/EMA resources
# could not find synonym for  FLUTICASONE PROPIONATE; FORMOTEROL FUMARATE HYDRATE  in list 1. Adding it to the list.
# found  FLUVOXAMINE MALEATE  in FDA/EMA resources
# found  FOLLITROPIN ALFA  in FDA/EMA resources
# found  FOLLITROPIN BETA  in FDA/EMA resources
# found  FOLLITROPIN DELTA  in FDA/EMA resources
# found  FOMEPIZOLE  in FDA/EMA resources
# found  FONDAPARINUX SODIUM  in FDA/EMA resources
# found synonym for  FORMOTEROL FUMARATE HYDRATE  in FDA/EMA resources
# found synonym for  FORMOTEROL FUMARATE HYDRATE  in FDA/EMA resources
# found synonym for  FORMOTEROL FUMARATE HYDRATE  in FDA/EMA resources
# could not find synonym for  FORMOTEROL FUMARATE HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  FORODESINE HYDROCHLORIDE  in list 1. Adding it to the list.
# could not find synonym for  FOSAMPRENAVIR CALCIUM HYDRATE  in list 1. Adding it to the list.
# found synonym for  FOSAPREPITANT MEGLUMINE  in FDA/EMA resources
# found synonym for  FOSAPREPITANT MEGLUMINE  in FDA/EMA resources
# could not find synonym for  FOSAPREPITANT MEGLUMINE  in list 1. Adding it to the list.
# found synonym for  FOSCARNET SODIUM HYDRATE  in FDA/EMA resources
# could not find synonym for  FOSCARNET SODIUM HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  FOSLEVODOPA; FOSCARBIDOPA HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  FOSNETUPITANT CHLORIDE HYDROCHLORIDE  in list 1. Adding it to the list.
# found synonym for  FOSPHENYTOIN SODIUM HYDRATE  in FDA/EMA resources
# could not find synonym for  FOSPHENYTOIN SODIUM HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  FOSRAVUCONAZOLE L- LYSINE ETHANOLATE  in list 1. Adding it to the list.
# could not find synonym for  FOSTAMATINIB SODIUM HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  FREEZE-DRIED ACTIVATED HUMAN BLOOD COAGULATION FACTOR VII CONCENTRATE CONTAINING FACTOR X  in list 1. Adding it to the list.
# could not find synonym for  FREEZE-DRIED BACILLUS OF CALMETTE AND GUERIN FOR INTRAVESICAL USE (CONNAUGHT STRAIN)  in list 1. Adding it to the list.
# could not find synonym for  FREEZE-DRIED HUMAN ACTIVATED PROTEIN C CONCENTRATED  in list 1. Adding it to the list.
# could not find synonym for  FREEZE-DRIED HUMAN FIBRINOGEN  in list 1. Adding it to the list.
# could not find synonym for  FREEZE-DRIED HUMAN PROTHROMBIN COMPLEX CONCENTRATED  in list 1. Adding it to the list.
# could not find synonym for  FREEZE-DRIED INACTIVATED  TISSUE CULTURE RABIES VACCINE  in list 1. Adding it to the list.
# could not find synonym for  FREEZE-DRIED INACTIVATED TISSUE CULTURE HEPATITIS A VACCINE  in list 1. Adding it to the list.
# could not find synonym for  FREEZE-DRIED ION- EXCHANGE-RESIN TREATED HUMAN NORMAL IMMUNOGLOBULIN  in list 1. Adding it to the list.
# could not find synonym for  FREEZE-DRIED LIVE ATTENUATED MEASLES AND RUBELLA COMBINED  in list 1. Adding it to the list.
# could not find synonym for  FREEZE-DRIED LIVE ATTENUATED MEASLES, RUBELLA COMBINED VACCINE  in list 1. Adding it to the list.
# could not find synonym for  FREEZE-DRIED LIVE ATTENUATED VARICELLA VACCINE  in list 1. Adding it to the list.
# could not find synonym for  FREEZE-DRIED PH4 TREATED HUMAN IMMUNOGLOBULIN  in list 1. Adding it to the list.
# could not find synonym for  FREEZE-DRIED POLYETHYLENE GLYCOL TREATED HUMAN NORMAL IMMUNOGLOBULIN  in list 1. Adding it to the list.
# could not find synonym for  FREEZE-DRIED RECOMBINANT HERPES ZOSTER VACCINE (PREPARED FROM CHINESE HAMSTER OVARY CELLS)  in list 1. Adding it to the list.
# could not find synonym for  FREEZE-DRIED SULFONATED HUMAN NORMAL IMMUNOGLOBULIN  in list 1. Adding it to the list.
# could not find synonym for  FREEZE-DRIED, CELL CULTURE- DERIVED JAPANESE ENCEPHALITIS VACCINE （INACTIVATED）  in list 1. Adding it to the list.
# found  FREMANEZUMAB  in FDA/EMA resources
# found  FULVESTRANT  in FDA/EMA resources
# found  FUTIBATINIB  in FDA/EMA resources
# found  GABAPENTIN  in FDA/EMA resources
# found  GABAPENTIN ENACARBIL  in FDA/EMA resources
# could not find synonym for  GADOBUTROL  in list 1. Adding it to the list.
# could not find synonym for  GADOXETATE SODIUM  in list 1. Adding it to the list.
# found  GALANTAMINE HYDROBROMIDE  in FDA/EMA resources
# found  GALCANEZUMAB  in FDA/EMA resources
# found  GALSULFASE  in FDA/EMA resources
# found  GANIRELIX ACETATE  in FDA/EMA resources
# could not find synonym for  GARENOXACIN MESILATE  in list 1. Adding it to the list.
# found  GATIFLOXACIN  in FDA/EMA resources
# found synonym for  GEFAPIXANT CITRATE  in FDA/EMA resources
# could not find synonym for  GEFAPIXANT CITRATE  in list 1. Adding it to the list.
# found  GEFITINIB  in FDA/EMA resources
# found  GEMCITABINE HYDROCHLORIDE  in FDA/EMA resources
# found  GEMTUZUMAB OZOGAMICIN  in FDA/EMA resources
# found  GENTAMICIN SULFATE  in FDA/EMA resources
# found  GILTERITINIB FUMARATE  in FDA/EMA resources
# found  GIVOSIRAN SODIUM  in FDA/EMA resources
# found  GLATIRAMER ACETATE  in FDA/EMA resources
# could not find synonym for  GLECAPREVIR HYDRATE; PIBRENTASVIR  in list 1. Adding it to the list.
# found  GLIMEPIRIDE  in FDA/EMA resources
# found  GLUCAGON  in FDA/EMA resources
# found  GLUCARPIDASE  in FDA/EMA resources
# found  GLYCOPYRRONIUM BROMIDE  in FDA/EMA resources
# could not find synonym for  GLYCOPYRRONIUM BROMIDE; FORMOTEROL FUMARATE HYDRATE  in list 1. Adding it to the list.
# found synonym for  GLYCOPYRRONIUM TOSILATE HYDRATE  in FDA/EMA resources
# found synonym for  GLYCOPYRRONIUM TOSILATE HYDRATE  in FDA/EMA resources
# found synonym for  GLYCOPYRRONIUM TOSILATE HYDRATE  in FDA/EMA resources
# could not find synonym for  GLYCOPYRRONIUM TOSILATE HYDRATE  in list 1. Adding it to the list.
# found  GOLIMUMAB  in FDA/EMA resources
# found  GOSERELIN ACETATE  in FDA/EMA resources
# found  GRANISETRON HYDROCHLORIDE  in FDA/EMA resources
# found synonym for  GRAZOPREVIR HYDRATE  in FDA/EMA resources
# could not find synonym for  GRAZOPREVIR HYDRATE  in list 1. Adding it to the list.
# found  GUANFACINE HYDROCHLORIDE  in FDA/EMA resources
# found  GUSELKUMAB  in FDA/EMA resources
# could not find synonym for  HAEMOPHILUS INFLUENZAE TYPE B POLYSACCHARIDE- TETANUS TOXOID CONJUGATE VACCINE  in list 1. Adding it to the list.
# could not find synonym for  HAEMOPHILUS INFLUENZAE TYPE B VACCINE ABSORBED (MUTATED DIPHTHERIA CRM197 CONJUGATE)  in list 1. Adding it to the list.
# could not find synonym for  HAEMOPHILUS INFLUENZAE TYPE B VACCINE ADSORBED (MUTATED DIPHTHERIA TOXIN CRM197 CONJUGATE)  in list 1. Adding it to the list.
# could not find synonym for  HEMIN  in list 1. Adding it to the list.
# found  HISTAMINE DIHYDROCHLORIDE  in FDA/EMA resources
# could not find synonym for  HPV-16 L1 VLP; HPV-18 L1 VLP  in list 1. Adding it to the list.
# could not find synonym for  HUMAN C1-INACTIVATOR  in list 1. Adding it to the list.
# could not find synonym for  HUMAN CHORIONIC GONADOTROPHIN  in list 1. Adding it to the list.
# could not find synonym for  HUMAN FIBRINOGEN; THROMBIN FRACTION  in list 1. Adding it to the list.
# could not find synonym for  HUMAN MENOPAUSAL GONADOTROPHIN  in list 1. Adding it to the list.
# could not find synonym for  HUMAN NORMAL IMMUNOGLOBULIN G (PH4-TREATED ACIDIC NORMAL HUMAN IMMUNOGLOBULIN [SUBCUTANEOUS INJECTION])  in list 1. Adding it to the list.
# could not find synonym for  HUMAN PAPILLOMAVIRUS L1 PROTEIN VIRUS-LIKE PARTICLES (TYPES 6, 11, 16, 18, 31, 33, 45, 52, AND 58)  in list 1. Adding it to the list.
# found  HUMAN PROTEIN C  in FDA/EMA resources
# could not find synonym for  HUMAN SERUM ALBUMIN  in list 1. Adding it to the list.
# could not find synonym for  HYDROCHLORIDE  in list 1. Adding it to the list.
# found  HYDROCORTISONE SODIUM SUCCINATE  in FDA/EMA resources
# found  HYDROMORPHONE HYDROCHLORIDE  in FDA/EMA resources
# found  HYDROXOCOBALAMIN  in FDA/EMA resources
# found  HYDROXYCARBAMIDE  in FDA/EMA resources
# found  HYDROXYCHLOROQUINE SULFATE  in FDA/EMA resources
# could not find synonym for  HYDROXYETHYLATED STARCH 130000  in list 1. Adding it to the list.
# could not find synonym for  IBANDRONATE SODIUM HYDRATE  in list 1. Adding it to the list.
# found  IBRUTINIB  in FDA/EMA resources
# could not find synonym for  IBUPROFEN L-LYSINE  in list 1. Adding it to the list.
# found  ICATIBANT ACETATE  in FDA/EMA resources
# found  IDARUCIZUMAB  in FDA/EMA resources
# found  IDURSULFASE  in FDA/EMA resources
# could not find synonym for  IDURSULFASE BETA  in list 1. Adding it to the list.
# found  IFOSFAMIDE  in FDA/EMA resources
# could not find synonym for  IGURATIMOD  in list 1. Adding it to the list.
# found  ILOPROST  in FDA/EMA resources
# found synonym for  IMATINIB MESILATE  in FDA/EMA resources
# found synonym for  IMATINIB MESILATE  in FDA/EMA resources
# could not find synonym for  IMATINIB MESILATE  in list 1. Adding it to the list.
# could not find synonym for  IMEGLIMIN HYDROCHLORIDE  in list 1. Adding it to the list.
# could not find synonym for  IMIDAFENACIN  in list 1. Adding it to the list.
# found  IMIQUIMOD  in FDA/EMA resources
# could not find synonym for  INACTIVATED INFLUENZA VIRUS, H5N1 (WHOLE VIRION)  in list 1. Adding it to the list.
# could not find synonym for  INACTIVATED JAPANESE ENCEPHALITIS VIRUS (BEIJING STRAIN)  in list 1. Adding it to the list.
# could not find synonym for  INACTIVATED POLIOMYELITIS VACCINE (SALK VACCINE)  in list 1. Adding it to the list.
# could not find synonym for  INACTIVATED SPLIT-VIRUS INFLUENZA A (A/CALIFORNIA/7/2009 [H1N1])  in list 1. Adding it to the list.
# could not find synonym for  INACTIVATED TICK-BORNE ENCEPHALITIS VIRUS  in list 1. Adding it to the list.
# found  INCLISIRAN SODIUM  in FDA/EMA resources
# found synonym for  INCOBOTULINUMTOXIN A  in FDA/EMA resources
# could not find synonym for  INCOBOTULINUMTOXIN A  in list 1. Adding it to the list.
# could not find synonym for  INDACATEROL ACETATE; GLYCOPYRRONIUM BROMIDE; MOMETASONE FUROATE  in list 1. Adding it to the list.
# could not find synonym for  INDACATEROL ACETATE; MOMETASONE FUROATE  in list 1. Adding it to the list.
# found  INDACATEROL MALEATE  in FDA/EMA resources
# could not find synonym for  INDIGOCARMINE  in list 1. Adding it to the list.
# could not find synonym for  INDIUM PENTETOREOTIDE (111IN)  in list 1. Adding it to the list.
# could not find synonym for  INDOCYANINE GREEN  in list 1. Adding it to the list.
# found  INEBILIZUMAB  in FDA/EMA resources
# found  INFLIXIMAB  in FDA/EMA resources
# could not find synonym for  INFLUENZA HA VACCINE  in list 1. Adding it to the list.
# found  INOTUZUMAB OZOGAMICIN  in FDA/EMA resources
# found  INSULIN ASPART  in FDA/EMA resources
# could not find synonym for  INSULIN ASPART  [INSULIN ASPART BIOSIMILAR 1]  in list 1. Adding it to the list.
# found  INSULIN DEGLUDEC  in FDA/EMA resources
# could not find synonym for  INSULIN DEGLUDEC; INSULIN ASPART  in list 1. Adding it to the list.
# could not find synonym for  INSULIN DEGLUDEC; LIRAGLUTIDE  in list 1. Adding it to the list.
# found  INSULIN DETEMIR  in FDA/EMA resources
# found  INSULIN GLARGINE  in FDA/EMA resources
# could not find synonym for  INSULIN GLARGINE; LIXISENATIDE  in list 1. Adding it to the list.
# found  INSULIN GLULISINE  in FDA/EMA resources
# found  INSULIN HUMAN  in FDA/EMA resources
# found  INSULIN LISPRO  in FDA/EMA resources
# could not find synonym for  INSULIN LISPRO  [INSULIN LISPRO BIOSIMILAR 1]  in list 1. Adding it to the list.
# could not find synonym for  INTERFERON ALFA (NAMALWA)  in list 1. Adding it to the list.
# found  INTERFERON ALFA-2B  in FDA/EMA resources
# could not find synonym for  INTERFERON BETA  in list 1. Adding it to the list.
# found  INTERFERON BETA-1A  in FDA/EMA resources
# could not find synonym for  INTERFERON GAMMA-1A  in list 1. Adding it to the list.
# found  INULIN  in FDA/EMA resources
# could not find synonym for  IODINE ADDITION PRODUCTS OF THE ETHYL ESTERS OF THE FATTY ACIDS OBTAINED FROM POPPYSEED OIL  in list 1. Adding it to the list.
# could not find synonym for  IOMEPROL  in list 1. Adding it to the list.
# could not find synonym for  IOVERSOL  in list 1. Adding it to the list.
# found  IPILIMUMAB  in FDA/EMA resources
# could not find synonym for  IPRAGLIFLOZIN L-PROLINE  in list 1. Adding it to the list.
# found  IRBESARTAN  in FDA/EMA resources
# could not find synonym for  IRBESARTAN; AMLODIPINE BESILATE  in list 1. Adding it to the list.
# could not find synonym for  IRBESARTAN; TRICHLORMETHIAZIDE  in list 1. Adding it to the list.
# found synonym for  IRINOTECAN HYDROCHLORIDE HYDRATE  in FDA/EMA resources
# found synonym for  IRINOTECAN HYDROCHLORIDE HYDRATE  in FDA/EMA resources
# could not find synonym for  IRINOTECAN HYDROCHLORIDE HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  IRON (III) HEXACYANOFERRATE (II)  in list 1. Adding it to the list.
# found  ISATUXIMAB  in FDA/EMA resources
# found  ISAVUCONAZONIUM SULFATE  in FDA/EMA resources
# found  ISTRADEFYLLINE  in FDA/EMA resources
# found  ITRACONAZOLE  in FDA/EMA resources
# found  IVABRADINE HYDROCHLORIDE  in FDA/EMA resources
# found  IVERMECTIN  in FDA/EMA resources
# found  IXAZOMIB CITRATE  in FDA/EMA resources
# found  IXEKIZUMAB  in FDA/EMA resources
# ...
# found  ROZANOLIXIZUMAB  in FDA/EMA resources
# found  RUFINAMIDE  in FDA/EMA resources
# could not find synonym for  RUPATADINE FUMARATE  in list 1. Adding it to the list.
# could not find synonym for  RURIOCTOCOG ALFA  in list 1. Adding it to the list.
# found  RURIOCTOCOG ALFA PEGOL  in FDA/EMA resources
# found  RUXOLITINIB PHOSPHATE  in FDA/EMA resources
# could not find synonym for  SACUBITRIL VALSARTAN SODIUM HYDRATE  in list 1. Adding it to the list.
# found synonym for  SAFINAMIDE MESILATE  in FDA/EMA resources
# found synonym for  SAFINAMIDE MESILATE  in FDA/EMA resources
# could not find synonym for  SAFINAMIDE MESILATE  in list 1. Adding it to the list.
# could not find synonym for  SALMETEROL XINAFOATE; FLUTICASONE PROPIONATE  in list 1. Adding it to the list.
# found synonym for  SAPROPTERIN HYDROCHLORIDE  in FDA/EMA resources
# found synonym for  SAPROPTERIN HYDROCHLORIDE  in FDA/EMA resources
# could not find synonym for  SAPROPTERIN HYDROCHLORIDE  in list 1. Adding it to the list.
# found synonym for  SAQUINAVIR MESILATE  in FDA/EMA resources
# found synonym for  SAQUINAVIR MESILATE  in FDA/EMA resources
# could not find synonym for  SAQUINAVIR MESILATE  in list 1. Adding it to the list.
# found  SARGRAMOSTIM  in FDA/EMA resources
# found  SARILUMAB  in FDA/EMA resources
# found  SATRALIZUMAB  in FDA/EMA resources
# found synonym for  SAXAGLIPTIN HYDRATE  in FDA/EMA resources
# found synonym for  SAXAGLIPTIN HYDRATE  in FDA/EMA resources
# could not find synonym for  SAXAGLIPTIN HYDRATE  in list 1. Adding it to the list.
# found  SEBELIPASE ALFA  in FDA/EMA resources
# found  SECUKINUMAB  in FDA/EMA resources
# found  SELEGILINE HYDROCHLORIDE  in FDA/EMA resources
# found  SELEXIPAG  in FDA/EMA resources
# found  SELPERCATINIB  in FDA/EMA resources
# found  SELUMETINIB SULFATE  in FDA/EMA resources
# found  SEMAGLUTIDE  in FDA/EMA resources
# found  SERTRALINE HYDROCHLORIDE  in FDA/EMA resources
# found  SILDENAFIL CITRATE  in FDA/EMA resources
# found synonym for  SILODOSHIN  in FDA/EMA resources
# could not find synonym for  SILODOSHIN  in list 1. Adding it to the list.
# found  SIMEPREVIR SODIUM  in FDA/EMA resources
# found  SIMOCTOCOG ALFA  in FDA/EMA resources
# found synonym for  SIPONIMOD FUMARIC ACID  in FDA/EMA resources
# could not find synonym for  SIPONIMOD FUMARIC ACID  in list 1. Adding it to the list.
# found  SIROLIMUS  in FDA/EMA resources
# could not find synonym for  SITAFLOXACIN HYDRATE  in list 1. Adding it to the list.
# found synonym for  SITAGLIPTIN PHOSPHATE HYDRATE  in FDA/EMA resources
# found synonym for  SITAGLIPTIN PHOSPHATE HYDRATE  in FDA/EMA resources
# found synonym for  SITAGLIPTIN PHOSPHATE HYDRATE  in FDA/EMA resources
# could not find synonym for  SITAGLIPTIN PHOSPHATE HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  SITAGLIPTIN PHOSPHATE HYDRATE; IPRAGLIFLOZIN L- PROLINE  in list 1. Adding it to the list.
# could not find synonym for  SODIUM FLUORIDE  in list 1. Adding it to the list.
# could not find synonym for  SODIUM HYALURONATE CROSSLINKED POLYMER; SODIUM HYALURONATE CROSSLINKED POLYMER CROSSLINKED WITH VINYLSULFONE  in list 1. Adding it to the list.
# could not find synonym for  SODIUM HYALURONATE; CHONDROITIN SULFATE SODIUM  in list 1. Adding it to the list.
# found synonym for  SODIUM LOXOPROFEN  in FDA/EMA resources
# could not find synonym for  SODIUM LOXOPROFEN  in list 1. Adding it to the list.
# found synonym for  SODIUM NITROPRUSSIDE HYDRATE  in FDA/EMA resources
# could not find synonym for  SODIUM NITROPRUSSIDE HYDRATE  in list 1. Adding it to the list.
# found  SODIUM PHENYLBUTYRATE  in FDA/EMA resources
# could not find synonym for  SODIUM PHYTATE  in list 1. Adding it to the list.
# could not find synonym for  SODIUM PICOSULFATE HYDRATE; MAGNESIUM OXIDE; ANHYDROUS CITRIC ACID  in list 1. Adding it to the list.
# found synonym for  SODIUM RABEPRAZOLE  in FDA/EMA resources
# could not find synonym for  SODIUM RABEPRAZOLE  in list 1. Adding it to the list.
# could not find synonym for  SODIUM RABEPRAZOLE AMOXICILLIN CLARITHROMYCIN  in list 1. Adding it to the list.
# found synonym for  SODIUM RISEDRONATE HYDRATE  in FDA/EMA resources
# found synonym for  SODIUM RISEDRONATE HYDRATE  in FDA/EMA resources
# could not find synonym for  SODIUM RISEDRONATE HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  SODIUM SELENITE  in list 1. Adding it to the list.
# found synonym for  SODIUM VALPROATE  in FDA/EMA resources
# found synonym for  SODIUM VALPROATE  in FDA/EMA resources
# found synonym for  SODIUM VALPROATE  in FDA/EMA resources
# could not find synonym for  SODIUM VALPROATE  in list 1. Adding it to the list.
# could not find synonym for  SODIUM ZIRCONIUM CYCLOSILICATE HYDRATE  in list 1. Adding it to the list.
# found  SOFOSBUVIR  in FDA/EMA resources
# found  SOFOSBUVIR; VELPATASVIR  in FDA/EMA resources
# found  SOFPIRONIUM BROMIDE  in FDA/EMA resources
# found  SOLIFENACIN SUCCINATE  in FDA/EMA resources
# found  SOMAPACITAN  in FDA/EMA resources
# found  SOMATROGON  in FDA/EMA resources
# found  SOMATROPIN  in FDA/EMA resources
# found synonym for  SORAFENIB TOSILATE  in FDA/EMA resources
# found synonym for  SORAFENIB TOSILATE  in FDA/EMA resources
# could not find synonym for  SORAFENIB TOSILATE  in list 1. Adding it to the list.
# found  SOTORASIB  in FDA/EMA resources
# found  SOTROVIMAB  in FDA/EMA resources
# found  SPESOLIMAB  in FDA/EMA resources
# could not find synonym for  SPIRAMYCIN  in list 1. Adding it to the list.
# could not find synonym for  STANDARDIZED JAPANESE CEDAR POLLEN EXTRACT ORIGINAL SOLUTION 10,000 JAU/ML  in list 1. Adding it to the list.
# found synonym for  STERILE TALC  in FDA/EMA resources
# could not find synonym for  STERILE TALC  in list 1. Adding it to the list.
# found  STIRIPENTOL  in FDA/EMA resources
# found  STREPTOMYCIN SULFATE  in FDA/EMA resources
# found  STREPTOZOCIN  in FDA/EMA resources
# could not find synonym for  STRONTIUM (89SR) CHLORIDE  in list 1. Adding it to the list.
# found  SUCROFERRIC OXYHYDROXIDE  in FDA/EMA resources
# found  SUGAMMADEX SODIUM  in FDA/EMA resources
# could not find synonym for  SULBACTAM SODIUM; AMPICILLIN SODIUM  in list 1. Adding it to the list.
# found  SULFAMETHOXAZOLE; TRIMETHOPRIM  in FDA/EMA resources
# could not find synonym for  SULFATE; TAZOBACTAM SODIUM  in list 1. Adding it to the list.
# found  SUNITINIB MALATE  in FDA/EMA resources
# found  SUSOCTOCOG ALFA  in FDA/EMA resources
# found  SUTIMLIMAB  in FDA/EMA resources
# found  SUVOREXANT  in FDA/EMA resources
# could not find synonym for  TACALCITOL  in list 1. Adding it to the list.
# found synonym for  TACROLIMUS HYDRATE  in FDA/EMA resources
# could not find synonym for  TACROLIMUS HYDRATE  in list 1. Adding it to the list.
# found  TADALAFIL  in FDA/EMA resources
# found  TAFAMIDIS  in FDA/EMA resources
# found  TAFAMIDIS MEGLUMINE  in FDA/EMA resources
# found  TAFLUPROST  in FDA/EMA resources
# could not find synonym for  TAFLUPROST TIMOLOL MALEATE  in list 1. Adding it to the list.
# could not find synonym for  TALAPORFIN SODIUM  in list 1. Adding it to the list.
# could not find synonym for  TALAZOPARIB TOSILATE  in list 1. Adding it to the list.
# found  TALC  in FDA/EMA resources
# could not find synonym for  TAMIBAROTENE  in list 1. Adding it to the list.
# found  TAPENTADOL HYDROCHLORIDE  in FDA/EMA resources
# could not find synonym for  TAURINE  in list 1. Adding it to the list.
# found  TAZEMETOSTAT HYDROBROMIDE  in FDA/EMA resources
# could not find synonym for  TAZOBACTAM; PIPERACILLIN HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  TEBIPENEM PIVOXIL  in list 1. Adding it to the list.
# could not find synonym for  TECELEUKIN  in list 1. Adding it to the list.
# found  TEDIZOLID PHOSPHATE  in FDA/EMA resources
# found  TEDUGLUTIDE  in FDA/EMA resources
# could not find synonym for  TEGAFUR; GIMERACIL; OTERACIL POTASSIUM  in list 1. Adding it to the list.
# found  TELAPREVIR  in FDA/EMA resources
# could not find synonym for  TELMISARTAN; AMLODIPINE BESILATE  in list 1. Adding it to the list.
# could not find synonym for  TELMISARTAN; AMLODIPINE BESILATE; HYDROCHLOROTHIAZIDE  in list 1. Adding it to the list.
# could not find synonym for  TELMISARTAN; HYDROCHLOROTHIAZIDE  in list 1. Adding it to the list.
# found  TEMOZOLOMIDE  in FDA/EMA resources
# found  TEMSIROLIMUS  in FDA/EMA resources
# found  TENAPANOR HYDROCHLORIDE  in FDA/EMA resources
# could not find synonym for  TENELIGLIPTIN HYDROBROMIDE HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  TENELIGLIPTIN HYDROBROMIDE HYDRATE; CANAGLIFLOZIN HYDRATE  in list 1. Adding it to the list.
# found  TENOFOVIR ALAFENAMIDE FUMARATE  in FDA/EMA resources
# found  TENOFOVIR DISOPROXIL FUMARATE  in FDA/EMA resources
# could not find synonym for  TEPOTINIB HYDROCHLORIDE HYDRATE  in list 1. Adding it to the list.
# found  TERIPARATIDE  in FDA/EMA resources
# found  TETRABENAZINE  in FDA/EMA resources
# could not find synonym for  TETRAKIS (2-METHOXY- ISOBUTYL ISONITRILE) COPPER (I) TETRAFLUOROBORATE  in list 1. Adding it to the list.
# found  TEZEPELUMAB  in FDA/EMA resources
# found  THALIDOMIDE  in FDA/EMA resources
# found  THIOTEPA  in FDA/EMA resources
# could not find synonym for  THROMBOMODULIN ALFA  in list 1. Adding it to the list.
# could not find synonym for  THYROTROPIN HUMAN ALFA  in list 1. Adding it to the list.
# found  TICAGRELOR  in FDA/EMA resources
# found  TIGECYCLINE  in FDA/EMA resources
# found  TILDRAKIZUMAB  in FDA/EMA resources
# found synonym for  TIOTROPIUM BROMIDE HYDRATE  in FDA/EMA resources
# could not find synonym for  TIOTROPIUM BROMIDE HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  TIOTROPIUM BROMIDE HYDRATE; OLODATEROL HYDROCHLORIDE  in list 1. Adding it to the list.
# could not find synonym for  TIRABRUTINIB HYDROCHLORIDE  in list 1. Adding it to the list.
# found  TIRZEPATIDE  in FDA/EMA resources
# could not find synonym for  TIXAGEVIMAB; CILGAVIMAB  in list 1. Adding it to the list.
# found  TOBRAMYCIN  in FDA/EMA resources
# found  TOCILIZUMAB  in FDA/EMA resources
# found  TOFACITINIB CITRATE  in FDA/EMA resources
# could not find synonym for  TOFOGLIFLOZIN HYDRATE  in list 1. Adding it to the list.
# found  TOLTERODINE TARTRATE  in FDA/EMA resources
# found  TOLVAPTAN  in FDA/EMA resources
# found synonym for  TOLVAPTAN SODIUM PHOSPHATE  in FDA/EMA resources
# could not find synonym for  TOLVAPTAN SODIUM PHOSPHATE  in list 1. Adding it to the list.
# found  TOPIRAMATE  in FDA/EMA resources
# could not find synonym for  TOPIROXOSTAT  in list 1. Adding it to the list.
# could not find synonym for  TOSUFLOXACIN TOSILATE  in list 1. Adding it to the list.
# found  TOZINAMERAN  in FDA/EMA resources
# could not find synonym for  TOZINAMERAN TOZINAMERAN; FAMTOZINAMERAN  in list 1. Adding it to the list.
# could not find synonym for  TOZINAMERAN TOZINAMERAN; RILTOZINAMERAN  in list 1. Adding it to the list.
# could not find synonym for  TOZINAMERAN; TOZINAMERAN; FAMTOZINAMERAN; TOZINAMERAN; RILTOZINAMERAN (2)-(4) TOZINAMERAN; TOZINAMERAN; FAMTOZINAMERAN  in list 1. Adding it to the list.
# found  TRABECTEDIN  in FDA/EMA resources
# could not find synonym for  TRAFERMIN  in list 1. Adding it to the list.
# found  TRALOKINUMAB  in FDA/EMA resources
# found  TRAMADOL HYDROCHLORIDE  in FDA/EMA resources
# could not find synonym for  TRAMADOL HYDROCHLORIDE; ACETAMINOPHEN  in list 1. Adding it to the list.
# found  TRAMETINIB DIMETHYL SULFOXIDE  in FDA/EMA resources
# found  TRASTUZUMAB  in FDA/EMA resources
# found  TRASTUZUMAB DERUXTECAN  in FDA/EMA resources
# found  TRASTUZUMAB EMTANSINE  in FDA/EMA resources
# found  TRAVOPROST  in FDA/EMA resources
# could not find synonym for  TRAVOPROST; TIMOLOL MALEATE  in list 1. Adding it to the list.
# could not find synonym for  TRELAGLIPTIN SUCCINATE  in list 1. Adding it to the list.
# found  TREMELIMUMAB  in FDA/EMA resources
# found  TREPROSTINIL  in FDA/EMA resources
# found  TRIAMCINOLONE ACETONIDE  in FDA/EMA resources
# could not find synonym for  TRIFLURIDINE; TIPIRACIL HYDROCHLORIDE  in list 1. Adding it to the list.
# could not find synonym for  TUCIDINOSTAT  in list 1. Adding it to the list.
# found  TUROCTOCOG ALFA PEGOL  in FDA/EMA resources
# could not find synonym for  TUROCTOCOG ALPHA  in list 1. Adding it to the list.
# could not find synonym for  UFRENMERAN  in list 1. Adding it to the list.
# could not find synonym for  UFRENMERAN; MAFB- 7256A  in list 1. Adding it to the list.
# found  UMECLIDINIUM BROMIDE  in FDA/EMA resources
# could not find synonym for  UPACICALCET SODIUM HYDRATE  in list 1. Adding it to the list.
# found synonym for  UPADACITINIB HYDRATE  in FDA/EMA resources
# could not find synonym for  UPADACITINIB HYDRATE  in list 1. Adding it to the list.
# found synonym for  URSODEOXYCHOLIC ACID  in FDA/EMA resources
# could not find synonym for  URSODEOXYCHOLIC ACID  in list 1. Adding it to the list.
# found  USTEKINUMAB  in FDA/EMA resources
# found  VADADUSTAT  in FDA/EMA resources
# could not find synonym for  VALACICLOVIR HYDROCHLORIDE  in list 1. Adding it to the list.
# could not find synonym for  VALBENAZINE TOSILATE  in list 1. Adding it to the list.
# could not find synonym for  VALEMETOSTAT TOSILATE  in list 1. Adding it to the list.
# found  VALGANCICLOVIR HYDROCHLORIDE  in FDA/EMA resources
# found  VALSARTAN  in FDA/EMA resources
# could not find synonym for  VALSARTAN; AMLODIPINE BESYLATE  in list 1. Adding it to the list.
# could not find synonym for  VALSARTAN; CILNIDIPINE  in list 1. Adding it to the list.
# could not find synonym for  VALSARTAN; HYDROCHLOROTHIAZIDE  in list 1. Adding it to the list.
# found  VANCOMYCIN HYDROCHLORIDE  in FDA/EMA resources
# found  VANDETANIB  in FDA/EMA resources
# could not find synonym for  VANIPREVIR  in list 1. Adding it to the list.
# found  VARDENAFIL HYDROCHLORIDE  in FDA/EMA resources
# found  VARENICLINE TARTRATE  in FDA/EMA resources
# could not find synonym for  VARICELLA ZOSTER VIRUS GE ANTIGEN  in list 1. Adding it to the list.
# found  VEDOLIZUMAB  in FDA/EMA resources
# found  VELAGLUCERASE ALFA  in FDA/EMA resources
# found  VEMURAFENIB  in FDA/EMA resources
# found  VENETOCLAX  in FDA/EMA resources
# found  VENLAFAXINE HYDROCHLORIDE  in FDA/EMA resources
# found  VERAPAMIL HYDROCHLORIDE  in FDA/EMA resources
# found  VERICIGUAT  in FDA/EMA resources
# found  VESTRONIDASE ALFA  in FDA/EMA resources
# found  VIBEGRON  in FDA/EMA resources
# found  VIGABATRIN  in FDA/EMA resources
# could not find synonym for  VILANTEROL TRIFENATATE; FLUTICASONE FUROATE  in list 1. Adding it to the list.
# found  VILDAGLIPTIN  in FDA/EMA resources
# could not find synonym for  VILDAGLIPTIN; METFORMIN HYDROCHLORIDE  in list 1. Adding it to the list.
# found  VILTOLARSEN  in FDA/EMA resources
# found  VINBLASTINE SULFATE  in FDA/EMA resources
# found  VINCRISTINE SULFATE  in FDA/EMA resources
# found synonym for  VINORELBINE DITARTRATE  in FDA/EMA resources
# could not find synonym for  VINORELBINE DITARTRATE  in list 1. Adding it to the list.
# could not find synonym for  VOGLIBOSE  in list 1. Adding it to the list.
# found  VONICOG ALFA  in FDA/EMA resources
# found  VONOPRAZAN FUMARATE  in FDA/EMA resources
# found  VORICONAZOLE  in FDA/EMA resources
# found  VORINOSTAT  in FDA/EMA resources
# found  VORTIOXETINE HYDROBROMIDE  in FDA/EMA resources
# found  VOSORITIDE  in FDA/EMA resources
# found  VUTRISIRAN SODIUM  in FDA/EMA resources
# found  WARFARIN POTASSIUM  in FDA/EMA resources
# found synonym for  ZANAMIVIR HYDRATE  in FDA/EMA resources
# could not find synonym for  ZANAMIVIR HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  ZAPOMERAN  in list 1. Adding it to the list.
# found  ZILUCOPLAN SODIUM  in FDA/EMA resources
# found synonym for  ZINC ACETATE DIHYDRATE  in FDA/EMA resources
# could not find synonym for  ZINC ACETATE DIHYDRATE  in list 1. Adding it to the list.
# could not find synonym for  ZINC HISTIDINE HYDRATE  in list 1. Adding it to the list.
# could not find synonym for  ZOLBETUXIMAB  in list 1. Adding it to the list.
# found synonym for  ZOLEDRONIC ACID HYDRATE  in FDA/EMA resources
# could not find synonym for  ZOLEDRONIC ACID HYDRATE  in list 1. Adding it to the list.
# found  ZONISAMIDE  in FDA/EMA resources
