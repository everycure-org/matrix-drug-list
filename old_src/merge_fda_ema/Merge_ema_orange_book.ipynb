# %%
import os
import pandas as pd
import time
import math
import re
import psycopg2 as pg

# %%
def findSynonyms (string, synonyms):
    synonymIndices = []
    synonymIDs = list(synonyms.id)
    synonymsName = list(synonyms.name)
    if string in synonymsName:
        index = synonymsName.index(string)
        idNumber = synonymIDs[index]
        for ind, row in synonyms.iterrows():
            if row['id']==idNumber:
                synonymIndices.append(ind)
        for i in synonyms.name[synonymIndices]:
            i = i.upper()
    return list(synonyms.name[synonymIndices])


def build_map(list1, list2):
    print("map builder not written yet")

def mergeDrugLists(list1,list2, synonyms):
    newList = []
    
    for item in list1:
        newList.append(item)
        
    for item in list2:
        if item in newList:
            print("found ", item, " in FDA resources")
        if item not in newList:
            syns = findSynonyms(item, synonyms)
            foundSynonym = False
            for syn in syns:
                if syn in newList:
                    found=True
                    print("found synonym for ", item, " in FDA resources")

            if not foundSynonym:
                print("could not find synonym for ", item, " in list 1. Adding it to the list.")
                newList.append(item)
    return newList

      
oblist = pd.read_excel("../orange_book_ingest/fda_ob_list.xlsx")['Drug Name']
emalist = pd.read_excel("../ema_ingest/ema_list.xlsx")['Drug Name']
pblist = pd.read_excel("../purple_book_ingest/fda_pb_list.xlsx")['name']
#print(oblist,emalist)

connection = pg.connect(database="drugcentral", user="drugman", password="dosage", host="unmtid-dbs.net", port=5433)
synonyms = pd.read_sql("""select synonyms.* from synonyms""", con=connection)
DrugCentralEntries = pd.read_sql("""select structures.* from structures""", con=connection)
synonyms['name'] = synonyms['name'].str.upper()
print(synonyms)

ob_pb_list = mergeDrugLists(oblist, pblist, synonyms)
fda_ema_list = mergeDrugLists(ob_pb_list, emalist, synonyms)
final_list = list(set(fda_ema_list).difference(pd.read_excel("force_merge_fields.xlsx")['Field to Remove']))
sheetData = pd.DataFrame(data=[final_list]).transpose()
sheetData.columns = ['Drug Name']
sheetData.to_excel("fda_ema_merged_list.xlsx")
# Out:
# /var/folders/gm/d722cfgx1tdd8x4b5b1kd6j80000gn/T/ipykernel_53158/4095896746.py:48: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   synonyms = pd.read_sql("""select synonyms.* from synonyms""", con=connection)
# /var/folders/gm/d722cfgx1tdd8x4b5b1kd6j80000gn/T/ipykernel_53158/4095896746.py:49: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   DrugCentralEntries = pd.read_sql("""select structures.* from structures""", con=connection)
#        syn_id      id                                  name  preferred_name  \
# 0       23310  5391.0                           SACITUZUMAB             NaN
# 1       23311  5391.0                 SACITUZUMAB GOVITECAN             1.0
# 2       23312  5391.0            SACITUZUMAB GOVITECAN-HZIY             NaN
# 3       23313  5391.0                              TRODELVY             NaN
# 4       23314  5391.0                              IMMU-132             NaN
# ...       ...     ...                                   ...             ...
# 23364   25485  5234.0  DURVALUMAB (GENETICAL RECOMBINATION)             NaN
# 23365   25486  4210.0                                ELPLAT             NaN
# 23366   25487  4384.0          CALCIUM LEVOFOLINATE HYDRATE             NaN
# 23367   25488  4956.0              BEVACIZUMAB BIOSIMILAR 4             NaN
# 23368   25489  5268.0  EMICIZUMAB (GENETICAL RECOMBINATION)             NaN
#
#        parent_id                                 lname
# 0            NaN                           sacituzumab
# 1            NaN                 sacituzumab govitecan
# 2            NaN            sacituzumab govitecan-hziy
# 3            NaN                              trodelvy
# 4            NaN                              immu-132
# ...          ...                                   ...
# 23364        NaN  durvalumab (genetical recombination)
# 23365        NaN                                elplat
# 23366        NaN          calcium levofolinate hydrate
# 23367        NaN              bevacizumab biosimilar 4
# 23368        NaN  emicizumab (genetical recombination)
#
# [23369 rows x 6 columns]
# could not find synonym for  ABATACEPT  in list 1. Adding it to the list.
# could not find synonym for  ABCIXIMAB  in list 1. Adding it to the list.
# could not find synonym for  ADALIMUMAB  in list 1. Adding it to the list.
# could not find synonym for  ADUCANUMAB  in list 1. Adding it to the list.
# could not find synonym for  AFLIBERCEPT  in list 1. Adding it to the list.
# could not find synonym for  AGALSIDASE BETA  in list 1. Adding it to the list.
# could not find synonym for  ALBIGLUTIDE  in list 1. Adding it to the list.
# could not find synonym for  ALDESLEUKIN  in list 1. Adding it to the list.
# could not find synonym for  ALEFACEPT  in list 1. Adding it to the list.
# could not find synonym for  ALEMTUZUMAB  in list 1. Adding it to the list.
# could not find synonym for  ALGLUCOSIDASE ALFA  in list 1. Adding it to the list.
# could not find synonym for  ALIROCUMAB  in list 1. Adding it to the list.
# could not find synonym for  ALTEPLASE  in list 1. Adding it to the list.
# could not find synonym for  AMIVANTAMAB  in list 1. Adding it to the list.
# could not find synonym for  ANACAULASE  in list 1. Adding it to the list.
# could not find synonym for  ANAKINRA  in list 1. Adding it to the list.
# could not find synonym for  ANIFROLUMAB  in list 1. Adding it to the list.
# could not find synonym for  ANSUVIMAB  in list 1. Adding it to the list.
# could not find synonym for  APROTININ  in list 1. Adding it to the list.
# could not find synonym for  ASFOTASE ALFA  in list 1. Adding it to the list.
# could not find synonym for  ASPARAGINASE  in list 1. Adding it to the list.
# could not find synonym for  ATEZOLIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  AVALGLUCOSIDASE ALFA  in list 1. Adding it to the list.
# could not find synonym for  AVELUMAB  in list 1. Adding it to the list.
# could not find synonym for  BASILIXIMAB  in list 1. Adding it to the list.
# could not find synonym for  BECAPLERMIN  in list 1. Adding it to the list.
# could not find synonym for  BELANTAMAB MAFODOTIN  in list 1. Adding it to the list.
# could not find synonym for  BELATACEPT  in list 1. Adding it to the list.
# could not find synonym for  BELIMUMAB  in list 1. Adding it to the list.
# could not find synonym for  BENRALIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  BENZYLPENICILLOYL POLYLYSINE  in list 1. Adding it to the list.
# could not find synonym for  BERACTANT  in list 1. Adding it to the list.
# could not find synonym for  BEVACIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  BEZLOTOXUMAB  in list 1. Adding it to the list.
# could not find synonym for  BLINATUMOMAB  in list 1. Adding it to the list.
# could not find synonym for  BRENTUXIMAB VEDOTIN  in list 1. Adding it to the list.
# could not find synonym for  BRODALUMAB  in list 1. Adding it to the list.
# could not find synonym for  BROLUCIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  BUROSUMAB  in list 1. Adding it to the list.
# could not find synonym for  CALFACTANT  in list 1. Adding it to the list.
# could not find synonym for  CANAKINUMAB  in list 1. Adding it to the list.
# could not find synonym for  CAPLACIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  CEMIPLIMAB  in list 1. Adding it to the list.
# could not find synonym for  CERLIPONASE ALFA  in list 1. Adding it to the list.
# could not find synonym for  CERTOLIZUMAB PEGOL  in list 1. Adding it to the list.
# could not find synonym for  CETUXIMAB  in list 1. Adding it to the list.
# could not find synonym for  CHORIOGONADOTROPIN ALFA  in list 1. Adding it to the list.
# could not find synonym for  CHORIONIC GONADOTROPHIN  in list 1. Adding it to the list.
# could not find synonym for  CHYMOPAPAIN  in list 1. Adding it to the list.
# could not find synonym for  COLLAGENASE  in list 1. Adding it to the list.
# could not find synonym for  CORTICORELIN OVINE  in list 1. Adding it to the list.
# could not find synonym for  CRISANTASPASE  in list 1. Adding it to the list.
# could not find synonym for  CRIZANLIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  DACLIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  DARATUMUMAB  in list 1. Adding it to the list.
# could not find synonym for  DENILEUKIN DIFTITOX  in list 1. Adding it to the list.
# could not find synonym for  DENOSUMAB  in list 1. Adding it to the list.
# could not find synonym for  DESIRUDIN  in list 1. Adding it to the list.
# could not find synonym for  DINUTUXIMAB  in list 1. Adding it to the list.
# could not find synonym for  DORNASE ALFA  in list 1. Adding it to the list.
# could not find synonym for  DOSTARLIMAB  in list 1. Adding it to the list.
# could not find synonym for  DULAGLUTIDE  in list 1. Adding it to the list.
# could not find synonym for  DUPILUMAB  in list 1. Adding it to the list.
# could not find synonym for  DURVALUMAB  in list 1. Adding it to the list.
# could not find synonym for  ECALLANTIDE  in list 1. Adding it to the list.
# could not find synonym for  ECULIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  EFALIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  EFGARTIGIMOD ALFA  in list 1. Adding it to the list.
# could not find synonym for  EFLAPEGRASTIM  in list 1. Adding it to the list.
# could not find synonym for  ELAPEGADEMASE  in list 1. Adding it to the list.
# could not find synonym for  ELOSULFASE ALFA  in list 1. Adding it to the list.
# could not find synonym for  ELOTUZUMAB  in list 1. Adding it to the list.
# could not find synonym for  ELRANATAMAB  in list 1. Adding it to the list.
# could not find synonym for  EMAPALUMAB  in list 1. Adding it to the list.
# could not find synonym for  EMICIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  EPCORITAMAB  in list 1. Adding it to the list.
# could not find synonym for  EPOETIN ALFA  in list 1. Adding it to the list.
# could not find synonym for  EPTINEZUMAB  in list 1. Adding it to the list.
# could not find synonym for  ERENUMAB  in list 1. Adding it to the list.
# could not find synonym for  ETANERCEPT  in list 1. Adding it to the list.
# could not find synonym for  EVINACUMAB  in list 1. Adding it to the list.
# could not find synonym for  EVOLOCUMAB  in list 1. Adding it to the list.
# could not find synonym for  FARICIMAB  in list 1. Adding it to the list.
# could not find synonym for  FILGRASTIM  in list 1. Adding it to the list.
# could not find synonym for  FOLLITROPIN  in list 1. Adding it to the list.
# could not find synonym for  FREMANEZUMAB  in list 1. Adding it to the list.
# could not find synonym for  GALCANEZUMAB  in list 1. Adding it to the list.
# could not find synonym for  GEMTUZUMAB OZOGAMICIN  in list 1. Adding it to the list.
# could not find synonym for  GLOFITAMAB  in list 1. Adding it to the list.
# could not find synonym for  GLUCARPIDASE  in list 1. Adding it to the list.
# could not find synonym for  GOLIMUMAB  in list 1. Adding it to the list.
# could not find synonym for  GUSELKUMAB  in list 1. Adding it to the list.
# could not find synonym for  HYALURONIDASE  in list 1. Adding it to the list.
# could not find synonym for  IBALIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  IBRITUMOMAB TIUXETAN  in list 1. Adding it to the list.
# could not find synonym for  IDARUCIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  IDURSULFASE  in list 1. Adding it to the list.
# could not find synonym for  IMIGLUCERASE  in list 1. Adding it to the list.
# could not find synonym for  INEBILIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  INFLIXIMAB  in list 1. Adding it to the list.
# could not find synonym for  INOTUZUMAB OZOGAMICIN  in list 1. Adding it to the list.
# could not find synonym for  INSULIN ASPART  in list 1. Adding it to the list.
# could not find synonym for  INSULIN DEGLUDEC  in list 1. Adding it to the list.
# could not find synonym for  INSULIN DETEMIR  in list 1. Adding it to the list.
# could not find synonym for  INSULIN GLARGINE  in list 1. Adding it to the list.
# could not find synonym for  INSULIN GLULISINE  in list 1. Adding it to the list.
# could not find synonym for  INSULIN HUMAN  in list 1. Adding it to the list.
# could not find synonym for  INSULIN LISPRO  in list 1. Adding it to the list.
# could not find synonym for  INTERFERON ALFA-2B  in list 1. Adding it to the list.
# could not find synonym for  INTERFERON BETA-1A  in list 1. Adding it to the list.
# could not find synonym for  INTERFERON BETA-1B  in list 1. Adding it to the list.
# could not find synonym for  IPILIMUMAB  in list 1. Adding it to the list.
# could not find synonym for  ISATUXIMAB  in list 1. Adding it to the list.
# could not find synonym for  IXEKIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  LARONIDASE  in list 1. Adding it to the list.
# could not find synonym for  LECANEMAB  in list 1. Adding it to the list.
# could not find synonym for  LIXISENATIDE  in list 1. Adding it to the list.
# could not find synonym for  LONAPEGSOMATROPIN  in list 1. Adding it to the list.
# could not find synonym for  LONCASTUXIMAB TESIRINE  in list 1. Adding it to the list.
# could not find synonym for  LUSPATERCEPT  in list 1. Adding it to the list.
# could not find synonym for  MARGETUXIMAB  in list 1. Adding it to the list.
# could not find synonym for  MECASERMIN  in list 1. Adding it to the list.
# could not find synonym for  MECASERMIN RINFABATE  in list 1. Adding it to the list.
# could not find synonym for  MEPOLIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  METHOXY POLYETHYLENE GLYCOL-EPOETIN BETA  in list 1. Adding it to the list.
# could not find synonym for  METRELEPTIN  in list 1. Adding it to the list.
# could not find synonym for  MIRVETUXIMAB SORAVTANSINE  in list 1. Adding it to the list.
# could not find synonym for  MOGAMULIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  MOXETUMOMAB PASUDOTOX  in list 1. Adding it to the list.
# could not find synonym for  NATALIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  NAXITAMAB  in list 1. Adding it to the list.
# could not find synonym for  NECITUMUMAB  in list 1. Adding it to the list.
# could not find synonym for  NIRSEVIMAB  in list 1. Adding it to the list.
# could not find synonym for  NIVOLUMAB  in list 1. Adding it to the list.
# could not find synonym for  OBILTOXAXIMAB  in list 1. Adding it to the list.
# could not find synonym for  OBINUTUZUMAB  in list 1. Adding it to the list.
# could not find synonym for  OCRELIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  OCRIPLASMIN  in list 1. Adding it to the list.
# could not find synonym for  OFATUMUMAB  in list 1. Adding it to the list.
# could not find synonym for  OLARATUMAB  in list 1. Adding it to the list.
# could not find synonym for  OLIPUDASE ALFA  in list 1. Adding it to the list.
# could not find synonym for  OMALIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  ONASEMNOGENE ABEPARVOVEC  in list 1. Adding it to the list.
# could not find synonym for  OPRELVEKIN  in list 1. Adding it to the list.
# could not find synonym for  PALIFERMIN  in list 1. Adding it to the list.
# could not find synonym for  PALIVIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  PANCRELIPASE  in list 1. Adding it to the list.
# could not find synonym for  PANITUMUMAB  in list 1. Adding it to the list.
# could not find synonym for  PARATHYROID HORMONE  in list 1. Adding it to the list.
# could not find synonym for  PEGADEMASE  in list 1. Adding it to the list.
# could not find synonym for  PEGASPARGASE  in list 1. Adding it to the list.
# could not find synonym for  PEGFILGRASTIM  in list 1. Adding it to the list.
# could not find synonym for  PEGINTERFERON ALFA-2A  in list 1. Adding it to the list.
# could not find synonym for  PEGINTERFERON ALFA-2B  in list 1. Adding it to the list.
# could not find synonym for  PEGINTERFERON BETA-1A  in list 1. Adding it to the list.
# could not find synonym for  PEGLOTICASE  in list 1. Adding it to the list.
# could not find synonym for  PEGUNIGALSIDASE ALFA  in list 1. Adding it to the list.
# could not find synonym for  PEGVALIASE  in list 1. Adding it to the list.
# could not find synonym for  PEGVISOMANT  in list 1. Adding it to the list.
# could not find synonym for  PEMBROLIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  PERTUZUMAB  in list 1. Adding it to the list.
# could not find synonym for  POLATUZUMAB VEDOTIN  in list 1. Adding it to the list.
# could not find synonym for  PORACTANT ALFA  in list 1. Adding it to the list.
# could not find synonym for  POZELIMAB  in list 1. Adding it to the list.
# could not find synonym for  RAMUCIRUMAB  in list 1. Adding it to the list.
# could not find synonym for  RANIBIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  RASBURICASE  in list 1. Adding it to the list.
# could not find synonym for  RAVULIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  RAXIBACUMAB  in list 1. Adding it to the list.
# could not find synonym for  RESLIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  RETEPLASE  in list 1. Adding it to the list.
# could not find synonym for  RETIFANLIMAB  in list 1. Adding it to the list.
# could not find synonym for  RILONACEPT  in list 1. Adding it to the list.
# could not find synonym for  RISANKIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  RITUXIMAB  in list 1. Adding it to the list.
# could not find synonym for  ROMIPLOSTIM  in list 1. Adding it to the list.
# could not find synonym for  ROMOSOZUMAB  in list 1. Adding it to the list.
# could not find synonym for  ROPEGINTERFERON ALFA-2B  in list 1. Adding it to the list.
# could not find synonym for  ROZANOLIXIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  SACITUZUMAB GOVITECAN  in list 1. Adding it to the list.
# could not find synonym for  SACROSIDASE  in list 1. Adding it to the list.
# could not find synonym for  SARGRAMOSTIM  in list 1. Adding it to the list.
# could not find synonym for  SARILUMAB  in list 1. Adding it to the list.
# could not find synonym for  SATRALIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  SEBELIPASE ALFA  in list 1. Adding it to the list.
# could not find synonym for  SECUKINUMAB  in list 1. Adding it to the list.
# could not find synonym for  SILTUXIMAB  in list 1. Adding it to the list.
# could not find synonym for  SOMAPACITAN  in list 1. Adding it to the list.
# could not find synonym for  SOMATROPIN  in list 1. Adding it to the list.
# could not find synonym for  SPESOLIMAB  in list 1. Adding it to the list.
# could not find synonym for  SUTIMLIMAB  in list 1. Adding it to the list.
# could not find synonym for  TAFASITAMAB  in list 1. Adding it to the list.
# could not find synonym for  TAGRAXOFUSP  in list 1. Adding it to the list.
# could not find synonym for  TALIGLUCERASE ALFA  in list 1. Adding it to the list.
# could not find synonym for  TALIMOGENE LAHERPAREPVEC  in list 1. Adding it to the list.
# could not find synonym for  TALQUETAMAB  in list 1. Adding it to the list.
# could not find synonym for  TEBENTAFUSP  in list 1. Adding it to the list.
# could not find synonym for  TECHNETIUM (99MTC) NOFETUMOMAB MERPENTAN  in list 1. Adding it to the list.
# could not find synonym for  TECLISTAMAB  in list 1. Adding it to the list.
# could not find synonym for  TENECTEPLASE  in list 1. Adding it to the list.
# could not find synonym for  TEPLIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  TEPROTUMUMAB  in list 1. Adding it to the list.
# could not find synonym for  TESAMORELIN  in list 1. Adding it to the list.
# could not find synonym for  TEZEPELUMAB  in list 1. Adding it to the list.
# could not find synonym for  THYROTROPIN ALFA  in list 1. Adding it to the list.
# could not find synonym for  TILDRAKIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  TISOTUMAB VEDOTIN  in list 1. Adding it to the list.
# could not find synonym for  TOCILIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  TRASTUZUMAB  in list 1. Adding it to the list.
# could not find synonym for  TRASTUZUMAB DERUXTECAN  in list 1. Adding it to the list.
# could not find synonym for  TRASTUZUMAB EMTANSINE  in list 1. Adding it to the list.
# could not find synonym for  TREMELIMUMAB  in list 1. Adding it to the list.
# could not find synonym for  UBLITUXIMAB  in list 1. Adding it to the list.
# could not find synonym for  UROKINASE  in list 1. Adding it to the list.
# could not find synonym for  USTEKINUMAB  in list 1. Adding it to the list.
# could not find synonym for  VEDOLIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  VELAGLUCERASE ALFA  in list 1. Adding it to the list.
# could not find synonym for  VELMANASE  in list 1. Adding it to the list.
# could not find synonym for  VESTRONIDASE ALFA  in list 1. Adding it to the list.
# could not find synonym for  VONICOG ALFA  in list 1. Adding it to the list.
# could not find synonym for  TILMANOCEPT  in list 1. Adding it to the list.
# found  MARALIXIBAT CHLORIDE  in FDA resources
# could not find synonym for  COVID-19 MRNA VACCINE  in list 1. Adding it to the list.
# could not find synonym for  HUMAN FIBRINOGEN  in list 1. Adding it to the list.
# could not find synonym for  ALENDRONIC ACID, COLECALCIFEROL  in list 1. Adding it to the list.
# found  VOXELOTOR  in FDA resources
# found  PIRFENIDONE  in FDA resources
# found  DAROLUTAMIDE  in FDA resources
# found synonym for  OLOPATADINE  in FDA resources
# could not find synonym for  OLOPATADINE  in list 1. Adding it to the list.
# could not find synonym for  PADELIPORFIN  in list 1. Adding it to the list.
# could not find synonym for  AGALSIDASE ALFA  in list 1. Adding it to the list.
# found  TENECTEPLASE  in FDA resources
# found synonym for  GLYCOPYRRONIUM  in FDA resources
# could not find synonym for  GLYCOPYRRONIUM  in list 1. Adding it to the list.
# found  UMECLIDINIUM BROMIDE  in FDA resources
# could not find synonym for  LISOCABTAGENE MARALEUCEL  in list 1. Adding it to the list.
# found synonym for  ULIPRISTAL  in FDA resources
# could not find synonym for  ULIPRISTAL  in list 1. Adding it to the list.
# found  PEGUNIGALSIDASE ALFA  in FDA resources
# found synonym for  RALTEGRAVIR  in FDA resources
# could not find synonym for  RALTEGRAVIR  in list 1. Adding it to the list.
# found synonym for  DEFIBROTIDE  in FDA resources
# could not find synonym for  DEFIBROTIDE  in list 1. Adding it to the list.
# found synonym for  NIRAPARIB  in FDA resources
# could not find synonym for  NIRAPARIB  in list 1. Adding it to the list.
# could not find synonym for  NORELGESTROMIN  in list 1. Adding it to the list.
# could not find synonym for  POTASSIUM HYDROGEN CARBONATE  in list 1. Adding it to the list.
# could not find synonym for  LEDISPAVIR  in list 1. Adding it to the list.
# found synonym for  EMEDASTINE  in FDA resources
# could not find synonym for  EMEDASTINE  in list 1. Adding it to the list.
# could not find synonym for  TEZACAFTOR, IVACAFTOR  in list 1. Adding it to the list.
# found  AMBRISENTAN  in FDA resources
# found  RISANKIZUMAB  in FDA resources
# found synonym for  NINTEDANIB  in FDA resources
# could not find synonym for  NINTEDANIB  in list 1. Adding it to the list.
# found  MITOTANE  in FDA resources
# found  BUDESONIDE  in FDA resources
# found  INTERFERON BETA-1A  in FDA resources
# could not find synonym for  FAMTOZINAMERAN  in list 1. Adding it to the list.
# found  ENTACAPONE  in FDA resources
# could not find synonym for  CILASTATIN  in list 1. Adding it to the list.
# could not find synonym for  COPPER (64CU) CHLORIDE  in list 1. Adding it to the list.
# found  BEXAROTENE  in FDA resources
# found synonym for  SEVELAMER  in FDA resources
# could not find synonym for  SEVELAMER  in list 1. Adding it to the list.
# found  TIRZEPATIDE  in FDA resources
# found  TOLCAPONE  in FDA resources
# found synonym for  BEROTRALSTAT  in FDA resources
# could not find synonym for  BEROTRALSTAT  in list 1. Adding it to the list.
# could not find synonym for  AXICABTAGENE CILOLEUCEL  in list 1. Adding it to the list.
# found  TREMELIMUMAB  in FDA resources
# found  FERRIC MALTOL  in FDA resources
# found synonym for  5-AMINOLEVULINIC ACID HYDROCHLORIDE  in FDA resources
# could not find synonym for  5-AMINOLEVULINIC ACID HYDROCHLORIDE  in list 1. Adding it to the list.
# could not find synonym for  ELADOCAGENE EXUPARVOVEC  in list 1. Adding it to the list.
# could not find synonym for  EPTACOG BETA (ACTIVATED)  in list 1. Adding it to the list.
# could not find synonym for  EPOETIN ZETA  in list 1. Adding it to the list.
# found  THYROTROPIN ALFA  in FDA resources
# could not find synonym for  MEASLES, MUMPS, RUBELLA AND VARICELLA VACCINE (LIVE)  in list 1. Adding it to the list.
# found  TEMSIROLIMUS  in FDA resources
# could not find synonym for  HEPATITIS A (INACTIVATED) AND HEPATITIS B (RDNA) (HAB) VACCINE (ADSORBED)  in list 1. Adding it to the list.
# could not find synonym for  BUPRENORPHINE, NALOXONE  in list 1. Adding it to the list.
# found  FULVESTRANT  in FDA resources
# found  ASFOTASE ALFA  in FDA resources
# found  MEROPENEM  in FDA resources
# found  BARICITINIB  in FDA resources
# found  PRASTERONE  in FDA resources
# found synonym for  LEFAMULIN  in FDA resources
# could not find synonym for  LEFAMULIN  in list 1. Adding it to the list.
# could not find synonym for  FORMOTEROL FUMARATE DIHYDRATE, GLYCOPYRRONIUM, BUDESONIDE  in list 1. Adding it to the list.
# could not find synonym for  EBOLA ZAIRE VACCINE (RVSV∆G-ZEBOV-GP, LIVE)  in list 1. Adding it to the list.
# found synonym for  MITAPIVAT  in FDA resources
# could not find synonym for  MITAPIVAT  in list 1. Adding it to the list.
# found  CABOTEGRAVIR  in FDA resources
# found synonym for  INOTERSEN  in FDA resources
# could not find synonym for  INOTERSEN  in list 1. Adding it to the list.
# found  SELINEXOR  in FDA resources
# found  TADALAFIL  in FDA resources
# found  ROFLUMILAST  in FDA resources
# found  ROMOSOZUMAB  in FDA resources
# could not find synonym for  SOLRIAMFETOL  in list 1. Adding it to the list.
# found  CARFILZOMIB  in FDA resources
# found  RELUGOLIX  in FDA resources
# found  DECITABINE  in FDA resources
# could not find synonym for  NOMEGESTROL  in list 1. Adding it to the list.
# found  ABATACEPT  in FDA resources
# found  SEMAGLUTIDE  in FDA resources
# could not find synonym for  HUMAN PAPILLOMAVIRUS 9-VALENT VACCINE (RECOMBINANT, ADSORBED)  in list 1. Adding it to the list.
# could not find synonym for  BIMEKIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  HUMAN NORMAL IMMUNOGLOBULIN (SCIG)  in list 1. Adding it to the list.
# found  OSPEMIFENE  in FDA resources
# found  TALIMOGENE LAHERPAREPVEC  in FDA resources
# could not find synonym for  ALBUTREPENONACOG ALFA  in list 1. Adding it to the list.
# found  SELEXIPAG  in FDA resources
# found  MIRABEGRON  in FDA resources
# found  VORICONAZOLE  in FDA resources
# found synonym for  SELUMETINIB  in FDA resources
# could not find synonym for  SELUMETINIB  in list 1. Adding it to the list.
# found  AFAMELANOTIDE  in FDA resources
# could not find synonym for  LEDISPAVIR, SOFOSBUVIR  in list 1. Adding it to the list.
# could not find synonym for  MIFAMURTIDE  in list 1. Adding it to the list.
# could not find synonym for  EFMOROCTOCOG ALFA  in list 1. Adding it to the list.
# could not find synonym for  DARVADSTROCEL  in list 1. Adding it to the list.
# found  AZATHIOPRINE  in FDA resources
# could not find synonym for  TAZOBACTAM  in list 1. Adding it to the list.
# found synonym for  PANTOPRAZOLE  in FDA resources
# could not find synonym for  PANTOPRAZOLE  in list 1. Adding it to the list.
# found synonym for  COBIMETINIB  in FDA resources
# could not find synonym for  COBIMETINIB  in list 1. Adding it to the list.
# found synonym for  CABOZANTINIB  in FDA resources
# could not find synonym for  CABOZANTINIB  in list 1. Adding it to the list.
# could not find synonym for  ELEXACAFTOR  in list 1. Adding it to the list.
# could not find synonym for  GLECAPREVIR, PIBRENTASVIR  in list 1. Adding it to the list.
# could not find synonym for  INSULIN DEGLUDEC, INSULIN ASPART  in list 1. Adding it to the list.
# found  OLIPUDASE ALFA  in FDA resources
# found synonym for  RIMEGEPANT  in FDA resources
# could not find synonym for  RIMEGEPANT  in list 1. Adding it to the list.
# found  POTASSIUM CITRATE  in FDA resources
# could not find synonym for  ERAVACYCLINE  in list 1. Adding it to the list.
# found synonym for  SALMETEROL  in FDA resources
# could not find synonym for  SALMETEROL  in list 1. Adding it to the list.
# found  RANOLAZINE  in FDA resources
# could not find synonym for  ATALUREN  in list 1. Adding it to the list.
# found  ENCORAFENIB  in FDA resources
# could not find synonym for  COVID-19 VACCINE (RECOMBINANT, ADJUVANTED)  in list 1. Adding it to the list.
# found  APREPITANT  in FDA resources
# found  HYDROCORTISONE  in FDA resources
# could not find synonym for  ALPHA1-PROTEINASE INHIBITOR (HUMAN)  in list 1. Adding it to the list.
# found  DOCETAXEL  in FDA resources
# found  ETANERCEPT  in FDA resources
# found  TOBRAMYCIN  in FDA resources
# found synonym for  NERATINIB  in FDA resources
# could not find synonym for  NERATINIB  in list 1. Adding it to the list.
# found synonym for  PROPRANOLOL  in FDA resources
# could not find synonym for  PROPRANOLOL  in list 1. Adding it to the list.
# found  CENOBAMATE  in FDA resources
# could not find synonym for  ERTUGLIFLOZIN, METFORMIN HYDROCHLORIDE  in list 1. Adding it to the list.
# could not find synonym for  SULPHUR HEXAFLUORIDE  in list 1. Adding it to the list.
# found synonym for  PARA-AMINOSALICYLIC ACID  in FDA resources
# found synonym for  PARA-AMINOSALICYLIC ACID  in FDA resources
# found synonym for  PARA-AMINOSALICYLIC ACID  in FDA resources
# found synonym for  PARA-AMINOSALICYLIC ACID  in FDA resources
# could not find synonym for  PARA-AMINOSALICYLIC ACID  in list 1. Adding it to the list.
# found synonym for  TRIENTINE DIHYDROCHLORIDE  in FDA resources
# found synonym for  TRIENTINE DIHYDROCHLORIDE  in FDA resources
# could not find synonym for  TRIENTINE DIHYDROCHLORIDE  in list 1. Adding it to the list.
# found  THIOTEPA  in FDA resources
# could not find synonym for  LONOCTOCOG ALFA  in list 1. Adding it to the list.
# could not find synonym for  ANDUSOMERAN  in list 1. Adding it to the list.
# found  BRINZOLAMIDE  in FDA resources
# found synonym for  PRASUGREL  in FDA resources
# could not find synonym for  PRASUGREL  in list 1. Adding it to the list.
# found synonym for  RALOXIFENE  in FDA resources
# could not find synonym for  RALOXIFENE  in list 1. Adding it to the list.
# could not find synonym for  BUDESONIDE, FORMOTEROL  in list 1. Adding it to the list.
# found synonym for  LAROTRECTINIB  in FDA resources
# could not find synonym for  LAROTRECTINIB  in list 1. Adding it to the list.
# could not find synonym for  SALMETEROL, FLUTICASONE PROPIONATE  in list 1. Adding it to the list.
# found  LIDOCAINE  in FDA resources
# found  DEUCRAVACITINIB  in FDA resources
# found  RILUZOLE  in FDA resources
# found  SILODOSIN  in FDA resources
# found  NIVOLUMAB  in FDA resources
# found synonym for  NUSINERSEN  in FDA resources
# could not find synonym for  NUSINERSEN  in list 1. Adding it to the list.
# found  PEGINTERFERON BETA-1A  in FDA resources
# found synonym for  DELAFLOXACIN  in FDA resources
# could not find synonym for  DELAFLOXACIN  in list 1. Adding it to the list.
# found  PONESIMOD  in FDA resources
# found  CERLIPONASE ALFA  in FDA resources
# found synonym for  SILDENAFIL  in FDA resources
# could not find synonym for  SILDENAFIL  in list 1. Adding it to the list.
# found synonym for  BOSENTAN MONOHYDRATE  in FDA resources
# could not find synonym for  BOSENTAN MONOHYDRATE  in list 1. Adding it to the list.
# found synonym for  FORMOTEROL FUMARATE DIHYDRATE  in FDA resources
# could not find synonym for  FORMOTEROL FUMARATE DIHYDRATE  in list 1. Adding it to the list.
# found  PEGVISOMANT  in FDA resources
# found synonym for  PRILOCAINE  in FDA resources
# could not find synonym for  PRILOCAINE  in list 1. Adding it to the list.
# found  CEFTAZIDIME  in FDA resources
# found synonym for  COLESEVELAM  in FDA resources
# could not find synonym for  COLESEVELAM  in list 1. Adding it to the list.
# could not find synonym for  ISAVUCONAZOLE  in list 1. Adding it to the list.
# found synonym for  NETARSUDIL  in FDA resources
# could not find synonym for  NETARSUDIL  in list 1. Adding it to the list.
# could not find synonym for  ABACAVIR (AS SULFATE)  in list 1. Adding it to the list.
# could not find synonym for  HEPATITIS B SURFACE ANTIGEN  in list 1. Adding it to the list.
# could not find synonym for  BIRCH BARK EXTRACT  in list 1. Adding it to the list.
# could not find synonym for  RESPIRATORY SYNCYTIAL VIRUS VACCINE (BIVALENT, RECOMBINANT)  in list 1. Adding it to the list.
# found  PREGABALIN  in FDA resources
# could not find synonym for  LUMACAFTOR, IVACAFTOR  in list 1. Adding it to the list.
# could not find synonym for  MOROCTOCOG ALFA  in list 1. Adding it to the list.
# found  ONASEMNOGENE ABEPARVOVEC  in FDA resources
# found  FONDAPARINUX SODIUM  in FDA resources
# found synonym for  FINGOLIMOD  in FDA resources
# could not find synonym for  FINGOLIMOD  in list 1. Adding it to the list.
# found  INTERFERON BETA-1B  in FDA resources
# could not find synonym for  NONACOG GAMMA  in list 1. Adding it to the list.
# found  CRIZOTINIB  in FDA resources
# could not find synonym for  AVIBACTAM  in list 1. Adding it to the list.
# found  RAMUCIRUMAB  in FDA resources
# found synonym for  FOSAMPRENAVIR  in FDA resources
# could not find synonym for  FOSAMPRENAVIR  in list 1. Adding it to the list.
# found synonym for  ASCIMINIB  in FDA resources
# could not find synonym for  ASCIMINIB  in list 1. Adding it to the list.
# found  ESTRADIOL  in FDA resources
# found synonym for  VELMANASE ALFA  in FDA resources
# could not find synonym for  VELMANASE ALFA  in list 1. Adding it to the list.
# could not find synonym for  ARTENIMOL  in list 1. Adding it to the list.
# could not find synonym for  DEFATTED POWDER OF ARACHIS HYPOGAEA L., SEMEN (PEANUTS)  in list 1. Adding it to the list.
# found  LACOSAMIDE  in FDA resources
# could not find synonym for  TRALOKINUMAB  in list 1. Adding it to the list.
# found synonym for  HYDROXYCARBAMIDE  in FDA resources
# could not find synonym for  HYDROXYCARBAMIDE  in list 1. Adding it to the list.
# found  AVALGLUCOSIDASE ALFA  in FDA resources
# found  NELARABINE  in FDA resources
# found synonym for  DIFELIKEFALIN  in FDA resources
# could not find synonym for  DIFELIKEFALIN  in list 1. Adding it to the list.
# found synonym for  FORMOTEROL  in FDA resources
# found synonym for  FORMOTEROL  in FDA resources
# could not find synonym for  FORMOTEROL  in list 1. Adding it to the list.
# could not find synonym for  NIRMATRELVIR, RITONAVIR  in list 1. Adding it to the list.
# could not find synonym for  IVACAFTOR, TEZACAFTOR, ELEXACAFTOR  in list 1. Adding it to the list.
# found synonym for  AMLODIPINE  in FDA resources
# found synonym for  AMLODIPINE  in FDA resources
# could not find synonym for  AMLODIPINE  in list 1. Adding it to the list.
# could not find synonym for  HUMAN THROMBIN  in list 1. Adding it to the list.
# found synonym for  PANOBINOSTAT  in FDA resources
# could not find synonym for  PANOBINOSTAT  in list 1. Adding it to the list.
# found  ALIROCUMAB  in FDA resources
# found synonym for  OSILODROSTAT  in FDA resources
# could not find synonym for  OSILODROSTAT  in list 1. Adding it to the list.
# found  IMIQUIMOD  in FDA resources
# found  VIGABATRIN  in FDA resources
# could not find synonym for  BECLOMETASONE  in list 1. Adding it to the list.
# found  NALTREXONE  in FDA resources
# found  IXEKIZUMAB  in FDA resources
# could not find synonym for  VOXILAPREVI  in list 1. Adding it to the list.
# could not find synonym for  PIPERAQUINE TETRAPHOSPHATE  in list 1. Adding it to the list.
# could not find synonym for  UMECLIDINIUM BROMIDE, VILANTEROL  in list 1. Adding it to the list.
# found synonym for  PRUCALOPRIDE  in FDA resources
# could not find synonym for  PRUCALOPRIDE  in list 1. Adding it to the list.
# found  PIRTOBRUTINIB  in FDA resources
# found synonym for  ABACAVIR  in FDA resources
# could not find synonym for  ABACAVIR  in list 1. Adding it to the list.
# could not find synonym for  TIVOZANIB HYDROCHLORIDE MONOHYDRATE  in list 1. Adding it to the list.
# could not find synonym for  NIRAPARIB, ABIRATERONE ACETATE  in list 1. Adding it to the list.
# found  PARATHYROID HORMONE  in FDA resources
# found synonym for  TEPOTINIB  in FDA resources
# could not find synonym for  TEPOTINIB  in list 1. Adding it to the list.
# found  MIDAZOLAM  in FDA resources
# found  GRANISETRON  in FDA resources
# found  AMIVANTAMAB  in FDA resources
# found  BOSENTAN  in FDA resources
# could not find synonym for  INDACATEROL, GLYCOPYRRONIUM BROMIDE  in list 1. Adding it to the list.
# found synonym for  FENFLURAMINE  in FDA resources
# could not find synonym for  FENFLURAMINE  in list 1. Adding it to the list.
# found synonym for  ANAGRELIDE  in FDA resources
# could not find synonym for  ANAGRELIDE  in list 1. Adding it to the list.
# could not find synonym for  RILTOZINAMERAN  in list 1. Adding it to the list.
# could not find synonym for  CHOLERA VACCINE, ORAL, LIVE  in list 1. Adding it to the list.
# found  ASENAPINE  in FDA resources
# found  LINAGLIPTIN  in FDA resources
# found synonym for  ATAZANAVIR  in FDA resources
# could not find synonym for  ATAZANAVIR  in list 1. Adding it to the list.
# found synonym for  VARENICLINE  in FDA resources
# could not find synonym for  VARENICLINE  in list 1. Adding it to the list.
# could not find synonym for  CONESTAT ALFA  in list 1. Adding it to the list.
# found  PEGCETACOPLAN  in FDA resources
# found synonym for  ERLOTINIB  in FDA resources
# could not find synonym for  ERLOTINIB  in list 1. Adding it to the list.
# could not find synonym for  EFTRENONACOG ALFA  in list 1. Adding it to the list.
# found  TRIFLURIDINE  in FDA resources
# found synonym for  PAZOPANIB  in FDA resources
# could not find synonym for  PAZOPANIB  in list 1. Adding it to the list.
# found  ABALOPARATIDE  in FDA resources
# could not find synonym for  EPTACOG ALFA (ACTIVATED)  in list 1. Adding it to the list.
# could not find synonym for  INDACATEROL, GLYCOPYRRONIUM, MOMETASONE FUROATE  in list 1. Adding it to the list.
# found synonym for  TRAMETINIB  in FDA resources
# could not find synonym for  TRAMETINIB  in list 1. Adding it to the list.
# found  BEVACIZUMAB  in FDA resources
# found  IBRITUMOMAB TIUXETAN  in FDA resources
# found  FENTANYL  in FDA resources
# found  ABEMACICLIB  in FDA resources
# found synonym for  SETMELANOTIDE  in FDA resources
# could not find synonym for  SETMELANOTIDE  in list 1. Adding it to the list.
# could not find synonym for  DARUNAVIR, COBICISTAT, EMTRICITABINE, TENOFOVIR ALAFENAMIDE  in list 1. Adding it to the list.
# found synonym for  ACETYLSALICYLIC ACID  in FDA resources
# could not find synonym for  ACETYLSALICYLIC ACID  in list 1. Adding it to the list.
# found  SODIUM OXYBATE  in FDA resources
# found synonym for  RIBOCICLIB  in FDA resources
# could not find synonym for  RIBOCICLIB  in list 1. Adding it to the list.
# found synonym for  ELIGLUSTAT  in FDA resources
# could not find synonym for  ELIGLUSTAT  in list 1. Adding it to the list.
# found  PEMETREXED  in FDA resources
# found  GLYCEROL PHENYLBUTYRATE  in FDA resources
# found  ATOGEPANT  in FDA resources
# found  ETELCALCETIDE  in FDA resources
# found  MYCOPHENOLATE MOFETIL  in FDA resources
# could not find synonym for  ABACAVIR SULFATE / DOLUTEGRAVIR SODIUM / LAMIVUDINE  in list 1. Adding it to the list.
# could not find synonym for  HUMAN PAPILLOMAVIRUS VACCINE [TYPES 16, 18] (RECOMBINANT, ADJUVANTED, ADSORBED)  in list 1. Adding it to the list.
# found  IBUPROFEN  in FDA resources
# found synonym for  GIVOSIRAN  in FDA resources
# could not find synonym for  GIVOSIRAN  in list 1. Adding it to the list.
# found  ATEZOLIZUMAB  in FDA resources
# found  TEBENTAFUSP  in FDA resources
# found synonym for  ESKETAMINE  in FDA resources
# could not find synonym for  ESKETAMINE  in list 1. Adding it to the list.
# could not find synonym for  PIOGLITAZONE, METFORMIN  in list 1. Adding it to the list.
# found  LINACLOTIDE  in FDA resources
# could not find synonym for  NETUPITANT  in list 1. Adding it to the list.
# found  HYDROXOCOBALAMIN  in FDA resources
# could not find synonym for  BEMPEDOIC ACID, EZETIMIBE  in list 1. Adding it to the list.
# found  BROLUCIZUMAB  in FDA resources
# found  AVACOPAN  in FDA resources
# could not find synonym for  SITAGLIPTIN, METFORMIN  in list 1. Adding it to the list.
# found  TICAGRELOR  in FDA resources
# could not find synonym for  DINUTUXIMAB BETA  in list 1. Adding it to the list.
# found  VADADUSTAT  in FDA resources
# could not find synonym for  TRIFLURIDINE, TIPIRACIL  in list 1. Adding it to the list.
# found synonym for  EFLORNITHINE  in FDA resources
# could not find synonym for  EFLORNITHINE  in list 1. Adding it to the list.
# found synonym for  IRINOTECAN HYDROCHLORIDE TRIHYDRATE  in FDA resources
# could not find synonym for  IRINOTECAN HYDROCHLORIDE TRIHYDRATE  in list 1. Adding it to the list.
# could not find synonym for  PANDEMIC INFLUENZA VACCINE (H5N1) (SURFACE ANTIGEN, INACTIVATED, ADJUVANTED)  in list 1. Adding it to the list.
# found  PALBOCICLIB  in FDA resources
# found  PERAMPANEL  in FDA resources
# found  TECLISTAMAB  in FDA resources
# could not find synonym for  ATOSIBAN  in list 1. Adding it to the list.
# found  ANIFROLUMAB  in FDA resources
# found synonym for  TELOTRISTAT ETHYL  in FDA resources
# could not find synonym for  TELOTRISTAT ETHYL  in list 1. Adding it to the list.
# could not find synonym for  LYSINE  in list 1. Adding it to the list.
# found  SATRALIZUMAB  in FDA resources
# could not find synonym for  VILDAGLIPTIN  in list 1. Adding it to the list.
# could not find synonym for  TIPIRACIL  in list 1. Adding it to the list.
# found  ANIDULAFUNGIN  in FDA resources
# could not find synonym for  HUMAN PROTEIN C  in list 1. Adding it to the list.
# could not find synonym for  PANDEMIC INFLUENZA VACCINE (H5N1) (SPLIT VIRION, INACTIVATED, ADJUVANTED)  in list 1. Adding it to the list.
# found  GEFITINIB  in FDA resources
# found  SILTUXIMAB  in FDA resources
# found  ZOLEDRONIC ACID  in FDA resources
# found synonym for  MICAFUNGIN  in FDA resources
# could not find synonym for  MICAFUNGIN  in list 1. Adding it to the list.
# found  SELPERCATINIB  in FDA resources
# found synonym for  PALONOSETRON  in FDA resources
# could not find synonym for  PALONOSETRON  in list 1. Adding it to the list.
# could not find synonym for  PERFLUTREN  in list 1. Adding it to the list.
# could not find synonym for  HUMAN COAGULATION FACTOR X  in list 1. Adding it to the list.
# found  OPICAPONE  in FDA resources
# could not find synonym for  SITAGLIPTIN FUMARATE  in list 1. Adding it to the list.
# could not find synonym for  BOTULINUM TOXIN TYPE A  in list 1. Adding it to the list.
# found  PEGINTERFERON ALFA-2A  in FDA resources
# could not find synonym for  ROTAVIRUS VACCINE, LIVE  in list 1. Adding it to the list.
# could not find synonym for  SIMOCTOCOG ALFA  in list 1. Adding it to the list.
# could not find synonym for  CASIRIVIMAB, IMDEVIMAB  in list 1. Adding it to the list.
# found  GALCANEZUMAB  in FDA resources
# could not find synonym for  GEFAPIXANT  in list 1. Adding it to the list.
# could not find synonym for  DENGUE TETRAVALENT VACCINE (LIVE, ATTENUATED)  in list 1. Adding it to the list.
# found synonym for  ALECTINIB  in FDA resources
# could not find synonym for  ALECTINIB  in list 1. Adding it to the list.
# could not find synonym for  COVID-19 VACCINE (CHADOX1-S [RECOMBINANT])  in list 1. Adding it to the list.
# could not find synonym for  LANADELUMAB  in list 1. Adding it to the list.
# found synonym for  RILPIVIRINE  in FDA resources
# could not find synonym for  RILPIVIRINE  in list 1. Adding it to the list.
# could not find synonym for  LUTROPIN ALFA  in list 1. Adding it to the list.
# found  LUSPATERCEPT  in FDA resources
# found  CANAKINUMAB  in FDA resources
# found synonym for  PRAMIPEXOLE  in FDA resources
# could not find synonym for  PRAMIPEXOLE  in list 1. Adding it to the list.
# found  TOLVAPTAN  in FDA resources
# found  INOTUZUMAB OZOGAMICIN  in FDA resources
# found  SITAGLIPTIN  in FDA resources
# found  ROTIGOTINE  in FDA resources
# found  NIRSEVIMAB  in FDA resources
# could not find synonym for  VERNAKALANT HYDROCHLORIDE  in list 1. Adding it to the list.
# found  LONCASTUXIMAB TESIRINE  in FDA resources
# found synonym for  OCTREOTIDE  in FDA resources
# could not find synonym for  OCTREOTIDE  in list 1. Adding it to the list.
# found synonym for  DARIDOREXANT  in FDA resources
# could not find synonym for  DARIDOREXANT  in list 1. Adding it to the list.
# found  PACLITAXEL  in FDA resources
# found synonym for  RUCAPARIB  in FDA resources
# could not find synonym for  RUCAPARIB  in list 1. Adding it to the list.
# found  NEPAFENAC  in FDA resources
# found  ABIRATERONE ACETATE  in FDA resources
# found  EVEROLIMUS  in FDA resources
# found  PANITUMUMAB  in FDA resources
# could not find synonym for  BAZEDOXIFENE  in list 1. Adding it to the list.
# could not find synonym for  TEMOPORFIN  in list 1. Adding it to the list.
# found synonym for  SITAGLIPTIN HYDROCHLORIDE MONOHYDRATE  in FDA resources
# found synonym for  SITAGLIPTIN HYDROCHLORIDE MONOHYDRATE  in FDA resources
# could not find synonym for  SITAGLIPTIN HYDROCHLORIDE MONOHYDRATE  in list 1. Adding it to the list.
# found synonym for  METHYLTHIONINIUM CHLORIDE  in FDA resources
# could not find synonym for  METHYLTHIONINIUM CHLORIDE  in list 1. Adding it to the list.
# found  COLISTIMETHATE SODIUM  in FDA resources
# found  TRASTUZUMAB DERUXTECAN  in FDA resources
# found  IBRUTINIB  in FDA resources
# found synonym for  CHENODEOXYCHOLIC ACID  in FDA resources
# could not find synonym for  CHENODEOXYCHOLIC ACID  in list 1. Adding it to the list.
# found  EPTIFIBATIDE  in FDA resources
# could not find synonym for  SOMATROGON  in list 1. Adding it to the list.
# found  ARIPIPRAZOLE  in FDA resources
# could not find synonym for  TISAGENLECLEUCEL  in list 1. Adding it to the list.
# could not find synonym for  ANDEXANET ALFA  in list 1. Adding it to the list.
# found  BORTEZOMIB  in FDA resources
# could not find synonym for  VILANTEROL  in list 1. Adding it to the list.
# found  AZTREONAM  in FDA resources
# found  GLUCARPIDASE  in FDA resources
# could not find synonym for  TISLELIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  LINAGLIPTIN, METFORMIN HYDROCHLORIDE  in list 1. Adding it to the list.
# could not find synonym for  TIXAGEVIMAB, CILGAVIMAB  in list 1. Adding it to the list.
# could not find synonym for  ENFORTUMAB VEDOTIN  in list 1. Adding it to the list.
# found  SIPONIMOD  in FDA resources
# found  IPILIMUMAB  in FDA resources
# found  TEDIZOLID PHOSPHATE  in FDA resources
# found  SEVELAMER CARBONATE  in FDA resources
# found  RISPERIDONE  in FDA resources
# found  TASIMELTEON  in FDA resources
# found synonym for  AFATINIB  in FDA resources
# could not find synonym for  AFATINIB  in list 1. Adding it to the list.
# could not find synonym for  HUMAN COAGULATION FACTOR VIII / HUMAN VON WILLEBRAND FACTOR  in list 1. Adding it to the list.
# found  EZETIMIBE  in FDA resources
# could not find synonym for  BICTEGRAVIR, EMTRICITABINE, TENOFOVIR ALAFENAMIDE  in list 1. Adding it to the list.
# found synonym for  LEUPRORELIN  in FDA resources
# could not find synonym for  LEUPRORELIN  in list 1. Adding it to the list.
# found  EMTRICITABINE  in FDA resources
# found  INFLIXIMAB  in FDA resources
# could not find synonym for  SMALLPOX AND MONKEYPOX VACCINE (LIVE MODIFIED VACCINIA VIRUS ANKARA)  in list 1. Adding it to the list.
# found  SOTORASIB  in FDA resources
# found synonym for  ALISKIREN  in FDA resources
# could not find synonym for  ALISKIREN  in list 1. Adding it to the list.
# found  ENTECAVIR  in FDA resources
# found  BALOXAVIR MARBOXIL  in FDA resources
# found  CAPSAICIN  in FDA resources
# could not find synonym for  ANGIOTENSIN II  in list 1. Adding it to the list.
# could not find synonym for  SAXAGLIPTIN, METFORMIN HYDROCHLORIDE  in list 1. Adding it to the list.
# could not find synonym for  TOZINAMERAN, RILTOZINAMERAN AND TOZINAMERAN, FAMTOZINAMERAN AND TOZINAMERAN, COVID-19 MRNA VACCINE (NUCLEOSIDE MODIFIED)  in list 1. Adding it to the list.
# found  SACITUZUMAB GOVITECAN  in FDA resources
# found  SIMVASTATIN  in FDA resources
# found  BIMATOPROST  in FDA resources
# found  ULIPRISTAL ACETATE  in FDA resources
# found synonym for  MERCAPTAMINE  in FDA resources
# found synonym for  MERCAPTAMINE  in FDA resources
# could not find synonym for  MERCAPTAMINE  in list 1. Adding it to the list.
# found  RETEPLASE  in FDA resources
# found synonym for  IMATINIB  in FDA resources
# could not find synonym for  IMATINIB  in list 1. Adding it to the list.
# could not find synonym for  VOLANESORSEN  in list 1. Adding it to the list.
# could not find synonym for  GIMERACIL  in list 1. Adding it to the list.
# could not find synonym for  CANAGLIFLOZIN, METFORMIN  in list 1. Adding it to the list.
# found  ATAZANAVIR SULFATE  in FDA resources
# could not find synonym for  EMTRICITABINE, RILPIVIRINE, TENOFOVIR ALAFENAMIDE  in list 1. Adding it to the list.
# found  ETHINYL ESTRADIOL  in FDA resources
# found  AZACITIDINE  in FDA resources
# found  TACROLIMUS  in FDA resources
# could not find synonym for  TOZINAMERAN  in list 1. Adding it to the list.
# found  TIGECYCLINE  in FDA resources
# found synonym for  IBANDRONIC ACID  in FDA resources
# could not find synonym for  IBANDRONIC ACID  in list 1. Adding it to the list.
# found  AVANAFIL  in FDA resources
# found  SOFOSBUVIR  in FDA resources
# could not find synonym for  OMBITASVIR, PARITAPREVIR, RITONAVIR  in list 1. Adding it to the list.
# could not find synonym for  FOLLITROPIN ALFA, LUTROPIN ALFA  in list 1. Adding it to the list.
# found  PLERIXAFOR  in FDA resources
# found  RASBURICASE  in FDA resources
# ...
# could not find synonym for  EPOETIN THETA  in list 1. Adding it to the list.
# found synonym for  CETRORELIX  in FDA resources
# could not find synonym for  CETRORELIX  in list 1. Adding it to the list.
# found  COBICISTAT  in FDA resources
# found synonym for  FESOTERODINE  in FDA resources
# could not find synonym for  FESOTERODINE  in list 1. Adding it to the list.
# could not find synonym for  SITAGLIPTIN HYDROCHLORIDE MONOHYDRATE, METFORMIN HYDROCHLORIDE  in list 1. Adding it to the list.
# found  DEXAMETHASONE  in FDA resources
# found synonym for  BOSUTINIB  in FDA resources
# could not find synonym for  BOSUTINIB  in list 1. Adding it to the list.
# could not find synonym for  CEFTOLOZANE, TAZOBACTAM  in list 1. Adding it to the list.
# could not find synonym for  GALSULFASE  in list 1. Adding it to the list.
# could not find synonym for  POTASSIUM CITRATE, POTASSIUM HYDROGEN CARBONATE  in list 1. Adding it to the list.
# found synonym for  LAPATINIB  in FDA resources
# could not find synonym for  LAPATINIB  in list 1. Adding it to the list.
# could not find synonym for  RADIUM RA223 DICHLORIDE  in list 1. Adding it to the list.
# found synonym for  ELTROMBOPAG  in FDA resources
# could not find synonym for  ELTROMBOPAG  in list 1. Adding it to the list.
# found  RITONAVIR  in FDA resources
# found  ACALABRUTINIB  in FDA resources
# found synonym for  DULOXETINE  in FDA resources
# could not find synonym for  DULOXETINE  in list 1. Adding it to the list.
# found  VEMURAFENIB  in FDA resources
# could not find synonym for  DESLORATADINE, PSEUDOEPHEDRINE  in list 1. Adding it to the list.
# found  SPESOLIMAB  in FDA resources
# found  FENOFIBRATE  in FDA resources
# found synonym for  BEDAQUILINE  in FDA resources
# could not find synonym for  BEDAQUILINE  in list 1. Adding it to the list.
# could not find synonym for  BECLOMETASONE, FORMOTEROL, GLYCOPYRRONIUM BROMIDE  in list 1. Adding it to the list.
# could not find synonym for  NORELGESTROMIN, ETHINYL ESTRADIOL  in list 1. Adding it to the list.
# found  OBINUTUZUMAB  in FDA resources
# found  GOLIMUMAB  in FDA resources
# found  LENALIDOMIDE  in FDA resources
# found  ABACAVIR SULFATE  in FDA resources
# found  ALPELISIB  in FDA resources
# found  VERICIGUAT  in FDA resources
# could not find synonym for  FLUTICASONE FUROATE, VILANTEROL  in list 1. Adding it to the list.
# found  UPADACITINIB  in FDA resources
# could not find synonym for  BESILESOMAB  in list 1. Adding it to the list.
# found synonym for  AZILSARTAN MEDOXOMIL  in FDA resources
# could not find synonym for  AZILSARTAN MEDOXOMIL  in list 1. Adding it to the list.
# could not find synonym for  ETRANACOGENE DEZAPARVOVEC  in list 1. Adding it to the list.
# found synonym for  FOSTEMSAVIR  in FDA resources
# could not find synonym for  FOSTEMSAVIR  in list 1. Adding it to the list.
# found  VOSORITIDE  in FDA resources
# found  STIRIPENTOL  in FDA resources
# could not find synonym for  CIPAGLUCOSIDASE ALFA  in list 1. Adding it to the list.
# found synonym for  BRIMONIDINE  in FDA resources
# could not find synonym for  BRIMONIDINE  in list 1. Adding it to the list.
# could not find synonym for  TOCOFERSOLAN  in list 1. Adding it to the list.
# found  DENOSUMAB  in FDA resources
# found synonym for  DABIGATRAN ETEXILATE  in FDA resources
# could not find synonym for  DABIGATRAN ETEXILATE  in list 1. Adding it to the list.
# found  NITRIC OXIDE  in FDA resources
# could not find synonym for  VILDAGLIPTIN / METFORMIN HYDROCHLORIDE  in list 1. Adding it to the list.
# found synonym for  DRONEDARONE  in FDA resources
# could not find synonym for  DRONEDARONE  in list 1. Adding it to the list.
# found  ENZALUTAMIDE  in FDA resources
# found  VONICOG ALFA  in FDA resources
# found synonym for  ICATIBANT  in FDA resources
# could not find synonym for  ICATIBANT  in list 1. Adding it to the list.
# could not find synonym for  BRINZOLAMIDE, TIMOLOL  in list 1. Adding it to the list.
# found  BRIGATINIB  in FDA resources
# could not find synonym for  MIRIKIZUMAB  in list 1. Adding it to the list.
# could not find synonym for  SACUBITRIL  in list 1. Adding it to the list.
# found synonym for  REMIMAZOLAM  in FDA resources
# could not find synonym for  REMIMAZOLAM  in list 1. Adding it to the list.
# found synonym for  IXAZOMIB  in FDA resources
# could not find synonym for  IXAZOMIB  in list 1. Adding it to the list.
# could not find synonym for  PARECOXIB  in list 1. Adding it to the list.
# found  BELIMUMAB  in FDA resources
# found synonym for  GUANFACINE  in FDA resources
# could not find synonym for  GUANFACINE  in list 1. Adding it to the list.
# found  MIGLUSTAT  in FDA resources
# found synonym for  SORAFENIB  in FDA resources
# could not find synonym for  SORAFENIB  in list 1. Adding it to the list.
# found  VERTEPORFIN  in FDA resources
# found synonym for  CINACALCET  in FDA resources
# could not find synonym for  CINACALCET  in list 1. Adding it to the list.
# could not find synonym for  ATAZANAVIR, COBICISTAT  in list 1. Adding it to the list.
# could not find synonym for  MELATONIN  in list 1. Adding it to the list.
# could not find synonym for  HERPES ZOSTER VACCINE (RECOMBINANT, ADJUVANTED)  in list 1. Adding it to the list.
# found  ROMIPLOSTIM  in FDA resources
# found synonym for  SAXAGLIPTIN  in FDA resources
# could not find synonym for  SAXAGLIPTIN  in list 1. Adding it to the list.
# could not find synonym for  ELASOMERAN  in list 1. Adding it to the list.
# found synonym for  TENOFOVIR DISOPROXIL  in FDA resources
# could not find synonym for  TENOFOVIR DISOPROXIL  in list 1. Adding it to the list.
# could not find synonym for  OESTROGENS CONJUGATED, BAZEDOXIFENE  in list 1. Adding it to the list.
# found synonym for  PSEUDOEPHEDRINE  in FDA resources
# found synonym for  PSEUDOEPHEDRINE  in FDA resources
# found synonym for  PSEUDOEPHEDRINE  in FDA resources
# could not find synonym for  PSEUDOEPHEDRINE  in list 1. Adding it to the list.
# found  HYDROCHLOROTHIAZIDE  in FDA resources
# found  NATALIZUMAB  in FDA resources
# found  METHOTREXATE  in FDA resources
# found synonym for  PATISIRAN  in FDA resources
# could not find synonym for  PATISIRAN  in list 1. Adding it to the list.
# found  REGORAFENIB  in FDA resources
# found  CERITINIB  in FDA resources
# found synonym for  OSIMERTINIB  in FDA resources
# could not find synonym for  OSIMERTINIB  in list 1. Adding it to the list.
# could not find synonym for  ESTETROL, DROSPIRENONE  in list 1. Adding it to the list.
# could not find synonym for  JAPANESE ENCEPHALITIS VACCINE (INACTIVATED, ADSORBED)  in list 1. Adding it to the list.
# could not find synonym for  DARUNAVIR, COBICISTAT  in list 1. Adding it to the list.
# found  KETOCONAZOLE  in FDA resources
# could not find synonym for  CLOPIDOGREL, ACETYLSALICYLIC ACID  in list 1. Adding it to the list.
# could not find synonym for  INSULIN DEGLUDEC, LIRAGLUTIDE  in list 1. Adding it to the list.
# could not find synonym for  HEPATITIS A (INACTIVATED) AND HEPATITIS B (RDNA) (HAB) VACCINE (ADSORBED)  in list 1. Adding it to the list.
# could not find synonym for  PIOGLITAZONE, GLIMEPIRIDE  in list 1. Adding it to the list.
# found  DAPAGLIFLOZIN  in FDA resources
# found  SECUKINUMAB  in FDA resources
# could not find synonym for  DOLUTEGRAVIR, LAMIVUDINE  in list 1. Adding it to the list.
# found synonym for  SUFENTANIL  in FDA resources
# could not find synonym for  SUFENTANIL  in list 1. Adding it to the list.
# found  CHOLIC ACID  in FDA resources
# found  TRASTUZUMAB EMTANSINE  in FDA resources
# found  AXITINIB  in FDA resources
# found  UBLITUXIMAB  in FDA resources
# found  ARTESUNATE  in FDA resources
# found synonym for  PHENYLEPHRINE  in FDA resources
# could not find synonym for  PHENYLEPHRINE  in list 1. Adding it to the list.
# could not find synonym for  ACLIDINIUM BROMIDE, FORMOTEROL  in list 1. Adding it to the list.
# found  SODIUM THIOSULFATE  in FDA resources
# found  RIVAROXABAN  in FDA resources
# found  RANIBIZUMAB  in FDA resources
# could not find synonym for  CEDAZURIDINE, DECITABINE  in list 1. Adding it to the list.
# could not find synonym for  DASATINIB (ANHYDROUS)  in list 1. Adding it to the list.
# found  EFGARTIGIMOD ALFA  in FDA resources
# could not find synonym for  HUMAN HEPATITIS B IMMUNOGLOBULIN  in list 1. Adding it to the list.
# found  RAVULIZUMAB  in FDA resources
# could not find synonym for  INFLUENZA VACCINE (SURFACE ANTIGEN, INACTIVATED, PREPARED IN CELL CULTURES)  in list 1. Adding it to the list.
# could not find synonym for  ALOGLIPTIN, PIOGLITAZONE  in list 1. Adding it to the list.
# could not find synonym for  SUSOCTOCOG ALFA  in list 1. Adding it to the list.
# found  CYTARABINE  in FDA resources
# found  USTEKINUMAB  in FDA resources
# found  POMALIDOMIDE  in FDA resources
# found synonym for  BROMFENAC  in FDA resources
# could not find synonym for  BROMFENAC  in list 1. Adding it to the list.
# found synonym for  LUMASIRAN  in FDA resources
# could not find synonym for  LUMASIRAN  in list 1. Adding it to the list.
# found  BREXPIPRAZOLE  in FDA resources
# found  FIDAXOMICIN  in FDA resources
# found synonym for  DALBAVANCIN  in FDA resources
# could not find synonym for  DALBAVANCIN  in list 1. Adding it to the list.
# found  RESLIZUMAB  in FDA resources
# found  FINERENONE  in FDA resources
# found  REPAGLINIDE  in FDA resources
# found  TIRBANIBULIN  in FDA resources
# found synonym for  NORETHISTERONE ACETATE  in FDA resources
# could not find synonym for  NORETHISTERONE ACETATE  in list 1. Adding it to the list.
# could not find synonym for  DAVESOMERAN  in list 1. Adding it to the list.
# could not find synonym for  FORMOTEROL, GLYCOPYRRONIUM BROMIDE, BUDESONIDE  in list 1. Adding it to the list.
# could not find synonym for  LEVODOPA, CARBIDOPA, ENTACAPONE  in list 1. Adding it to the list.
# found  METHYLNALTREXONE BROMIDE  in FDA resources
# found synonym for  SUGAMMADEX  in FDA resources
# could not find synonym for  SUGAMMADEX  in list 1. Adding it to the list.
# found  VALSARTAN  in FDA resources
# found synonym for  MERCAPTAMINE BITARTRATE  in FDA resources
# found synonym for  MERCAPTAMINE BITARTRATE  in FDA resources
# found synonym for  MERCAPTAMINE BITARTRATE  in FDA resources
# could not find synonym for  MERCAPTAMINE BITARTRATE  in list 1. Adding it to the list.
# found synonym for  ORITAVANCIN  in FDA resources
# could not find synonym for  ORITAVANCIN  in list 1. Adding it to the list.
# found synonym for  ESOMEPRAZOLE  in FDA resources
# found synonym for  ESOMEPRAZOLE  in FDA resources
# found synonym for  ESOMEPRAZOLE  in FDA resources
# could not find synonym for  ESOMEPRAZOLE  in list 1. Adding it to the list.
# could not find synonym for  GOZETOTIDE  in list 1. Adding it to the list.
# found  LONAFARNIB  in FDA resources
# could not find synonym for  SAXAGLIPTIN, DAPAGLIFLOZIN  in list 1. Adding it to the list.
# found  GLOFITAMAB  in FDA resources
# could not find synonym for  LEBRIKIZUMAB  in list 1. Adding it to the list.
# found  REMDESIVIR  in FDA resources
# could not find synonym for  HUMAN PAPILLOMAVIRUS VACCINE [TYPES 6, 11, 16, 18] (RECOMBINANT, ADSORBED)  in list 1. Adding it to the list.
# found  INSULIN DETEMIR  in FDA resources
# could not find synonym for  SOFOSBUVIR, VELPATASVIR, VOXILAPREVI  in list 1. Adding it to the list.
# could not find synonym for  DIPHTHERIA, TETANUS, PERTUSSIS (ACELLULAR, COMPONENT), HEPATITIS B (RDNA), POLIOMYELITIS (INACTIVATED) AND HAEMOPHILUS TYPE B CONJUGATE VACCINE (ADSORBED)  in list 1. Adding it to the list.
# found synonym for  DOXORUBICIN  in FDA resources
# could not find synonym for  DOXORUBICIN  in list 1. Adding it to the list.
# could not find synonym for  RECOMBINANT RESPIRATORY SYNCYTIAL VIRUS PRE-FUSION F PROTEIN, ADJUVANTED WITH AS01E  in list 1. Adding it to the list.
# found  TRAVOPROST  in FDA resources
# could not find synonym for  OMBITASVIR  in list 1. Adding it to the list.
# found  DUVELISIB  in FDA resources
# found synonym for  PITOLISANT  in FDA resources
# could not find synonym for  PITOLISANT  in list 1. Adding it to the list.
# found  PALIPERIDONE  in FDA resources
# found  GLIMEPIRIDE  in FDA resources
# could not find synonym for  DORAVIRINE, LAMIVUDINE, TENOFOVIR DISOPROXIL  in list 1. Adding it to the list.
# found  PRETOMANID  in FDA resources
# could not find synonym for  AUTOLOGOUS CD34+ ENRICHED CELL FRACTION THAT CONTAINS CD34+ CELLS TRANSDUCED WITH RETROVIRAL VECTOR THAT ENCODES FOR THE HUMAN ADA CDNA SEQUENCE  in list 1. Adding it to the list.
# could not find synonym for  TELMISARTAN, AMLODIPINE  in list 1. Adding it to the list.
# found  SPIRONOLACTONE  in FDA resources
# found  SUTIMLIMAB  in FDA resources
# found  LIXISENATIDE  in FDA resources
# found  VENETOCLAX  in FDA resources
# found  VOCLOSPORIN  in FDA resources
# could not find synonym for  REGDANVIMAB  in list 1. Adding it to the list.
# found  SODIUM PHENYLBUTYRATE  in FDA resources
# found  CANAGLIFLOZIN  in FDA resources
# could not find synonym for  AGOMELATINE  in list 1. Adding it to the list.
# found  CEFTAROLINE FOSAMIL  in FDA resources
# found  AVAPRITINIB  in FDA resources
# could not find synonym for  SPHEROIDS OF HUMAN AUTOLOGOUS MATRIX-ASSOCIATED CHONDROCYTES  in list 1. Adding it to the list.
# could not find synonym for  ARGININE, LYSINE  in list 1. Adding it to the list.
# could not find synonym for  OCTOCOG ALFA  in list 1. Adding it to the list.
# could not find synonym for  HUMAN INSULIN (RDNA)  in list 1. Adding it to the list.
# found  PEMIGATINIB  in FDA resources
# could not find synonym for  DIPHTHERIA (D), TETANUS (T), PERTUSSIS (ACELLULAR, COMPONENT) (PA), HEPATITIS B (RDNA) (HBV), POLIOMYELITIS (INACTIVATED) (IPV) AND HAEMOPHILUS INFLUENZAE TYPE-B (HIB) CONJUGATE VACCINE (ADSORBED)  in list 1. Adding it to the list.
# found  BINIMETINIB  in FDA resources
# found  LATANOPROST  in FDA resources
# found  MEPOLIZUMAB  in FDA resources
# found  LEVODOPA  in FDA resources
# could not find synonym for  INCLISIRAN  in list 1. Adding it to the list.
# found  DAPTOMYCIN  in FDA resources
# found synonym for  ARGININE  in FDA resources
# could not find synonym for  ARGININE  in list 1. Adding it to the list.
# found  VANDETANIB  in FDA resources
# found  VEDOLIZUMAB  in FDA resources
# found  POLATUZUMAB VEDOTIN  in FDA resources
# could not find synonym for  IRBESARTAN, HYDROCHLOROTHIAZIDE  in list 1. Adding it to the list.
# found  ETRAVIRINE  in FDA resources
# found synonym for  SUCROFERRIC OXYHYDROXIDE  in FDA resources
# could not find synonym for  SUCROFERRIC OXYHYDROXIDE  in list 1. Adding it to the list.
# found  INEBILIZUMAB  in FDA resources
# found  BASILIXIMAB  in FDA resources
# found  ODEVIXIBAT  in FDA resources
# found  FILGRASTIM  in FDA resources
# found synonym for  GILTERITINIB  in FDA resources
# could not find synonym for  GILTERITINIB  in list 1. Adding it to the list.
# found  METFORMIN HYDROCHLORIDE  in FDA resources
# could not find synonym for  EX VIVO EXPANDED AUTOLOGOUS HUMAN CORNEAL EPITHELIAL CELLS CONTAINING STEM CELLS  in list 1. Adding it to the list.
# found  EPCORITAMAB  in FDA resources
# found  LORLATINIB  in FDA resources
# could not find synonym for  GRAZOPREVIR  in list 1. Adding it to the list.
# found synonym for  EDOXABAN  in FDA resources
# could not find synonym for  EDOXABAN  in list 1. Adding it to the list.
# found  MIDOSTAURIN  in FDA resources
# could not find synonym for  TEGAFUR  in list 1. Adding it to the list.
# found synonym for  SAPROPTERIN  in FDA resources
# could not find synonym for  SAPROPTERIN  in list 1. Adding it to the list.
# found  LETERMOVIR  in FDA resources
# found synonym for  TECOVIRIMAT MONOHYDRATE  in FDA resources
# could not find synonym for  TECOVIRIMAT MONOHYDRATE  in list 1. Adding it to the list.
# found  CANNABIDIOL  in FDA resources
# found  RIOCIGUAT  in FDA resources
# found  INSULIN GLARGINE  in FDA resources
# found  INSULIN GLULISINE  in FDA resources
# found  OBILTOXAXIMAB  in FDA resources
# found synonym for  AMIFAMPRIDINE  in FDA resources
# could not find synonym for  AMIFAMPRIDINE  in list 1. Adding it to the list.
# found  BEMPEDOIC ACID  in FDA resources
# could not find synonym for  NIRMATRELVIR  in list 1. Adding it to the list.
# found  CHORIOGONADOTROPIN ALFA  in FDA resources
# found  DOXORUBICIN HYDROCHLORIDE  in FDA resources
# found  RITUXIMAB  in FDA resources
